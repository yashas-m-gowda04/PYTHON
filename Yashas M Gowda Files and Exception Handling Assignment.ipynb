# %% [markdown]
# ## **Theory Questions**

# %% [markdown]
# ### **1. What is the difference between interpreted and compiled languages?**
#
# **Answer**:
#
# * **Interpreted (like Python)**: Code runs line-by-line using an interpreter. Slower, but easy to test.
#
# * **Compiled (like C++)**: Code is converted into machine code before running. Faster, but harder to debug.

# %% [markdown]
# ### **2. What is Exception Handling in Python?**
#
# **Answer**:
#
# Exception handling is how Python deals with errors without stopping the program.

# %%
try:
    a = 10 / 0
except ZeroDivisionError:
    print("Can't divide by zero")
# Out:
# Can't divide by zero

# %% [markdown]
# ### **3. What is the purpose of the finally block in exception handling?**
#
# **Answer**:
#
# The `finally` block always runs, whether there's an error or not. Useful for cleaning up (e.g., closing files).

# %%
f = None  # Initialize f to None
try:
    f = open("data.txt")
except:
    print("Error!")
finally:
    if f is not None: # Check if f is not None before closing
        f.close()
# Out:
# Error!

# %% [markdown]
# ### **4. What is Logging in Python?**
#
# **Answer**:
#
# Logging in Python is a robust and flexible standard library module that provides a system for emitting event messages from your programs. It's a more sophisticated and practical alternative to simply using `print()` statements for debugging and monitoring, especially for larger or production applications.
#
#
# **Core Purpose**:
#
# The primary purpose of logging is to keep a record of events that occur while your program is running. These events can include:
#
#   * **Informational messages**: Confirming that things are working as expected.
#
#   * **Warnings**: Indicating that something unexpected happened, or a potential problem is looming, but the software is still working.
#
#   * **Errors**: Signifying that the software has encountered a problem and cannot perform a function.
#
#   * **Critical errors**: Severe problems indicating that the program itself may be unable to continue.
#
#   * **Debugging information**: Detailed internal state of the program, useful for developers when diagnosing issues.

# %% [markdown]
# ### **5. What is the significance of the _ _ del_ _ method in Python?**
#
# **Answer**:
#
# This special method is called when an object is **deleted**.

# %%
class A:
    def __del__(self):
        print("Object deleted")

# %% [markdown]
# ### **6. What is the difference between import and from ... import in Python?**
#
# **Answer**:
#
# * `import math` → Use like `math.sqrt(4)`
#
# * `from math import sqrt` → Use like `sqrt(4)`

# %% [markdown]
# ### **7. How can you handle multiple exceptions in Python?**
#
# **Answer**:

# %%
try:
    a = int("abc")
    b = 1 / 0
except ValueError:
    print("Wrong value")
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Wrong value

# %% [markdown]
# ### **8. What is the purpose of the with statement when handling files in Python?**
#
# **Answer**:
#
# The `with` statement in Python is used when handling files to ensure that a file is properly closed after its suite finishes, even if exceptions are raised. It handles the opening and closing of the file automatically.

# %%
with open("my_file.txt", "w") as f:
    f.write("Hello, world!")

# %% [markdown]
# ### **9. What is the difference between multithreading and multiprocessing?**
#
# **Answer**:
#
# * **Multithreading**:
#
#   * **Defination**: Multiple threads run **within the same process**
#   * **Best for**: **I/O-bound tasks** (like file handling, API calls)
#   * **Memory Usage**: Threads share the same memory
#   * **Speed**: Faster for lightweight tasks
#   * **Crashes**: One thread crash can affect the whole process
#   * **Global Interpreter Lock (GIL)**: Affected by GIL (only one thread runs at a time in CPython)
#   * **Library Used**: `threading` module
#
# * **Multiprocessing**:
#
#   * **Defination**: Multiple **processes run independently**
#   * **Best for**: **CPU-bound tasks** (like heavy calculations)
#   * **Memory Usage**: Processes have **separate memory**
#   * **Speed**: Better performance for heavy tasks
#   * **Crashes**: Each process is isolated; one crash doesn’t affect others
#   * **Global Interpreter Lock (GIL)**: Each process is isolated; one crash doesn’t affect others
#   * **Library Used**: `multiprocessing` module
#
#   **Example**:
#
#
#  * **Multirhreading**:

# %%
import threading

def show():
    for i in range(5):
        print("Thread")

thread1 = threading.Thread(target=show)
thread1.start()
# Out:
# Thread
# Thread
# Thread
# Thread
# Thread

# %% [markdown]
# * **Multiprocessing**:

# %%
import multiprocessing

def show():
    for i in range(5):
        print("Process")

process1 = multiprocessing.Process(target=show)
process1.start()
# Out:
# Process

# %% [markdown]
# **Summary**:
#
# Use **multithreading** when tasks **wait for something** (like downloading, reading files).
#
# Use **multiprocessing** when tasks **need lots of computation power** (like data processing, ML training).

# %% [markdown]
# ### **10. What are the advantages of using logging in a program?**
#
# **Answer**:
#
# Using logging in a program offers several advantages:
#
# * **Debugging**: Provides a detailed history of what happened in the program, making it easier to identify and fix bugs.
#
# * **Monitoring**: Allows you to track the program's behavior in production, identifying potential issues before they become critical.
#
# * **Auditing**: Can be used to record significant events, user actions, or system changes for security or compliance purposes.
#
# * **Problem Diagnosis**: Helps in diagnosing issues in deployed applications without needing to attach a debugger.
#
# * **Separation of Concerns**: Keeps debugging/monitoring output separate from the main program output.
#
# * **Flexibility**: Python's `logging` module offers various levels (DEBUG, INFO, WARNING, ERROR, CRITICAL) and handlers (console, file, network, etc.) to control where and how messages are output.

# %% [markdown]
# ### **11. What is memory management in Python?**
#
# **Answer**:
#
# Memory management in Python involves how Python handles the allocation and deallocation of memory for objects. Key aspects include:
#
# * **Private Heaps**: Python has a private heap where all Python objects and data structures reside. Programmers do not directly control this heap.
#
# * **Automatic Memory Management**: Python uses a combination of techniques for automatic memory management:
#
# * **Reference Counting**: Each object has a reference count, which tracks how many references point to it. When the count drops to zero, the object's memory is deallocated.
#
# * **Garbage Collection (Generational Cyclic Garbage Collector)**: This mechanism deals with circular references (where objects refer to each other, preventing their reference counts from ever reaching zero). It periodically identifies and collects these unreachable cycles.
#
# * **Memory Pools**: For smaller objects, Python uses memory pools to allocate memory more efficiently, reducing the overhead of system calls for every small allocation.

# %% [markdown]
# ### **12. What are the basic steps involved in exception handling in Python?**
#
# **Answer**:
#
# The basic steps involved in exception handling in Python are:
#
# 1. `try` **block**: Code that might raise an exception is placed inside the `try` block.
#
# 2. `except` **block(s)**: If an exception occurs in the `try` block, the corresponding `except` block is executed. You can have multiple `except` blocks to handle different types of exceptions.
#
# 3. `else` **block (optional)**: This block is executed if no exception occurs in the `try` block.
#
# 4. `finally` **block (optional)**: This block is always executed, regardless of whether an exception occurred or not. It's typically used for cleanup operations.
#
# **Syntax**:

# %%
try:
    # Code that might raise an exception
    result = 10 / 0
except ZeroDivisionError:
    # Code to handle ZeroDivisionError
    print("Cannot divide by zero!")
except TypeError:
    # Code to handle TypeError
    print("Invalid type operation!")
else:
    # Code to execute if no exception occurred
    print("Division successful!")
finally:
    # Code that always executes (e.g., cleanup)
    print("Execution complete.")
# Out:
# Cannot divide by zero!
# Execution complete.

# %% [markdown]
# ### **13. Why is memory management important in Python?**
#
# **Answer**:
#
# Memory management is crucial in Python for several reasons:
#
# * **Resource Efficiency**: Efficient memory management prevents programs from consuming excessive amounts of RAM, which can lead to slow performance or even crashes, especially in long-running applications or those handling large datasets.
#
# * **Performance**: Unmanaged memory can lead to memory leaks (memory that is no longer needed but not released), causing the program to slow down over time as it requests more and more memory.
#
# * **Stability**: Proper memory management ensures that memory is allocated and deallocated correctly, preventing segmentation faults or other low-level errors that can destabilize the application.
#
# * **Scalability**: For applications that need to handle a growing number of users or data, efficient memory management is vital for scaling without hitting memory limitations.
#
# * **Automatic Handling**: While Python handles memory automatically, understanding its mechanisms helps developers write code that is memory-efficient and avoid patterns that could inadvertently lead to performance issues related to memory.

# %% [markdown]
# ### **14. What is the role of try and except in exception handling?**
#
# **Answer**:
#
# * `try`: The `try` block encloses the code that is expected to potentially raise an exception. It serves as a "monitor" for errors. If an exception occurs within the `try` block, the execution of the `try` block is immediately stopped, and Python looks for a matching `except` block.
#
# * `except`: The `except` block is responsible for handling specific types of exceptions that might be raised in the corresponding `try` block. When an exception occurs, Python checks if the type of the raised exception matches the type specified in an `except` block. If a match is found, the code within that `except` block is executed, allowing the program to gracefully recover or respond to the error instead of crashing.
#
# In essence, `try` identifies the potential problem area, and `except` provides the solution or alternative action when a problem arises.

# %% [markdown]
# ### **15. How does Python's garbage collection system work?**
#
# **Answer**:
#
# Python's garbage collection system primarily relies on two mechanisms:
#
# 1. **Reference Counting:**
#
#  * This is the primary and most immediate form of garbage collection.
#
#  * Every object in Python maintains a count of the number of references pointing to it.
#
#  * When an object's reference count drops to zero, it means there are no longer any variables or other objects referring to it.
#
#  * At this point, the memory occupied by that object is immediately deallocated and returned to the free list.
#
#  * **Limitation**: Reference counting cannot detect and collect objects that are part of a reference cycle. For example, if object A refers to B, and B refers to A, even if there are no external references to A or B, their reference counts will never drop to zero.
#
# 2. **Generational Cyclic Garbage Collector:**
#
#  * This is a supplemental garbage collector that runs periodically to address the limitation of reference counting (i.e., collecting circular references).
#
#  * It divides objects into "generations" (0, 1, 2, etc.) based on how long they have been alive. Newly created objects start in generation 0.
#
#  * Objects that survive a garbage collection cycle are promoted to an older generation. The intuition is that older objects are less likely to be garbage.
#
#  * The collector primarily focuses on checking newer generations more frequently, as they are more likely to contain objects that can be collected.
#
#  * When it runs, it identifies groups of objects that are mutually referencing each other but are no longer reachable from the root set (e.g., global variables, active stack frames). These unreachable cycles are then collected.
#
# In summary, reference counting handles most object deallocations instantly, while the generational cyclic garbage collector periodically sweeps for and collects objects involved in reference cycles.

# %% [markdown]
# ### **16. What is the purpose of the else block in exception handling?**
#
# **Answer**:
#
# The `else` block in exception handling is an optional part of the `try...except` statement. Its purpose is to contain code that should be executed only if no exception occurs in the `try` block.
#
# It provides a clean way to separate code that is critical for the success of the `try` block from code that should only run after that success is confirmed.
#
# **Example:**

# %%
try:
    file = open("my_data.txt", "r")
    content = file.read()
except FileNotFoundError:
    print("Error: The file was not found.")
else:
    print("File read successfully. Content:")
    print(content)
    file.close() # Only close if successfully opened and read
finally:
    print("Attempted file operation.")
# Out:
# Error: The file was not found.
# Attempted file operation.

# %% [markdown]
# In this example, `file.close()` is placed in `else` because it only makes sense to close the file if it was successfully opened and read. If `FileNotFoundError` occurs, `file` would not be a valid file object to close. The `finally` block could also be used for `file.close()` if `file` was guaranteed to be assigned even in case of an error (e.g., initialized to `None` beforehand).

# %% [markdown]
# ### **17. What are the common logging levels in Python?**
#
# **Answer**:
#
# Python's `logging` module provides a set of standard logging levels, ordered by increasing severity:
#
# 1. `DEBUG` **(10)**: Detailed information, typically of interest only when diagnosing problems.
#
# 2. `INFO` **(20)**: Confirmation that things are working as expected.
#
# 3. `WARNING` **(30)**: An indication that something unexpected happened, or indicative of some problem in the near future (e.g., 'disk space low'). The software is still working as expected.
#
# 4. `ERROR` **(40)**: Due to a more serious problem, the software has not been able to perform some function.
#
# 5. `CRITICAL` **(50)**: A serious error, indicating that the program itself may be unable to continue running.
#
# You can set a logging level for your logger, and only messages with that level or higher will be processed.

# %% [markdown]
# ### **18. What is the difference between os.fork() and multiprocessing in Python?**
#
# **Answer**:
#
# While both `os.fork()` and the `multiprocessing` module are used for creating new processes in Python, they represent different levels of abstraction and portability:
#
# * `os.fork()`:
#
#   * **Lower-level**: `os.fork()` is a direct wrapper around the Unix `fork()` system call.
#
#   * **Platform-specific**: It is only available on Unix-like systems (Linux, macOS, BSD). It does not work on Windows.
#
#   * **Process creation**: When `os.fork()` is called, it creates a new child process that is an almost identical copy of the parent process. The child process starts execution from the point where `fork()` was called.
#
#   * **Memory**: The child process initially shares memory with the parent via copy-on-write, meaning pages are copied only when one process modifies them.
#
#   * **Complexity**: Managing communication and synchronization between parent and child processes with `os.fork()` often requires lower-level mechanisms (e.g., pipes, shared memory, semaphores) that you implement manually.
#
# * `multiprocessing` **module**:
#
#   * **Higher-level**: The `multiprocessing` module provides a more abstract and object-oriented API for process management.
#
#   * **Cross-platform**: It works on both Unix-like systems and Windows (on Windows, it often uses `subprocess` under the hood or spawns new Python interpreters).
#
#   * **Process creation**: It provides classes like `Process`, `Pool`, and `Queue` that abstract away the complexities of process creation, communication, and synchronization.
#
#   * **Communication**: It offers built-in high-level mechanisms for inter-process communication (IPC) such as `Queue`, `Pipe`, `Value`, `Array`, and `Manager` for sharing data.
#
#   * **Ease of Use**: Generally easier to use for most multiprocessing needs, especially for complex scenarios or when cross-platform compatibility is required.
#
# **In summary**: `os.fork()` is a fundamental, low-level, Unix-specific function for creating processes. The `multiprocessing` module is a robust, high-level, cross-platform library built on top of `os.fork()` (or similar mechanisms on other OSes) that simplifies concurrent programming with processes. For most Python applications requiring multiprocessing, the `multiprocessing` module is the preferred choice due to its portability and ease of use.

# %% [markdown]
# ### **19. What is the importance of closing a file in Python?**
#
# **Answer**:
#
#
# Closing a file in Python is critically important for several reasons:
#
# 1. **Resource Release**: When you open a file, the operating system allocates resources (like file descriptors/handles) to your program. Closing the file releases these resources, making them available for other parts of your program or other applications. Failing to close files can lead to resource exhaustion, especially in long-running applications or those opening many files.
#
# 2. **Data Integrity/Persistence**: When you write to a file, the data is often buffered in memory before being physically written to disk. Closing the file explicitly flushes these buffers, ensuring that all data is written to the file and changes are saved. If a program crashes before a file is closed, data might be lost or corrupted.
#
# 3. **Preventing Locks**: On some operating systems, an open file might be locked, preventing other programs or even other parts of your own program from accessing or modifying it. Closing the file releases these locks.
#
# 4. **Avoiding Errors**: Reaching the maximum number of open files allowed by the operating system can cause `IOError` or `OSError` exceptions, preventing further file operations. Closing files as soon as they are no longer needed prevents this.
#
# 5. **Security**: In some contexts, leaving files open longer than necessary could pose a security risk, especially if the file contains sensitive information.
#
# The `with` statement (as discussed in Q8) is the recommended way to handle files because it automatically ensures that files are closed, even if errors occur, making your code safer and more robust.

# %% [markdown]
# ### **20. What is the difference between file.read() and file.readline() in Python?**
#
# **Answer**:
#
# Both `file.read()` and `file.readline()` are methods used to read data from a file object, but they differ in how much data they read:
#
# * `file.read(size=-1)`:
#
#   * Reads the entire content of the file as a single string.
#
#   * If an optional `size` argument is provided, it reads at most `size` bytes (or characters for text mode) from the file.
#
#   * After reading, the file pointer is at the end of the file (or after `size` bytes).
#
# **Example**:

# %%
# my_file.txt contains:
# Line 1
# Line 2
with open("my_file.txt", "r") as f:
    content = f.read()
    print(content)
# Output:
# Line 1
# Line 2
# Out:
# Hello, world!

# %% [markdown]
# * `file.readline(size=-1)`:
#
#  * Reads a single line from the file, including the newline character (`\n`) if present, until it encounters a newline or the end of the file.
#
#  * If an optional `size` argument is provided, it reads at most `size` bytes/characters, but it will still stop if a newline is encountered within that `size`.
#
#  * After reading, the file pointer is at the beginning of the next line.
#
#  **Example**:

# %%
# my_file.txt contains:
# Line 1
# Line 2
with open("my_file.txt", "r") as f:
    line1 = f.readline()
    line2 = f.readline()
    print(line1, end='') # Use end='' to avoid extra newline from print
    print(line2, end='')
# Output:
# Line 1
# Line 2
# Out:
# Hello, world!

# %% [markdown]
# **When to use which**:
#
# * Use `file.read()` when you need the entire content of a file (e.g., configuration files, small text files) or a specific number of bytes.
#
# * Use `file.readline()` when you want to process a file line by line (e.g., log files, CSV files where you need to parse each row sequentially). Iterating directly over the file object (e.g., `for line in file`:) is generally more efficient for line-by-line processing than calling `readline()` in a loop.

# %% [markdown]
# ### **21. What is the logging module in Python used for?**
#
# **Answer**:
#
# The `logging` module in Python is a powerful and flexible standard library module that provides a framework for emitting log messages from applications. Its primary uses include:
#
# * **Recording Events**: To keep a record of events that occur during the execution of a program, such as program start/end, user actions, data processing steps, or network communications.
#
# * **Debugging and Troubleshooting**: To provide diagnostic information that helps developers understand what went wrong when an error occurs or to track the flow of execution during development.
#
# * **Monitoring and Analysis**: In production environments, logs are crucial for monitoring the health and performance of an application, identifying trends, and performing post-mortem analysis of issues.
#
# * **Auditing and Compliance**: To record significant events for security audits, regulatory compliance, or to track data changes.
#
# * **Separating Output**: To keep informative and debugging messages separate from the program's normal output (e.g., user interface output).
#
# The `logging` module allows you to:
#
# * Define different **logging levels** (DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
# * Send log messages to various **destinations** (console, files, network sockets, email, etc.) using handlers.
#
# * Format log messages with **formatters** to include timestamps, log level, module name, etc.
#
# * Create multiple **loggers** for different parts of your application, allowing for fine-grained control over logging behavior.

# %% [markdown]
# ### **22. What is the os module in Python used for in file handling?**
#
# **Answer**:
#
# The `os` module in Python provides a way of using operating system dependent functionality. In the context of file handling, it is primarily used for:
#
# * **Path Manipulation**:
#
#  * `os.path.join()`: To construct platform-independent file paths.
#
#  * `os.path.exists()`: To check if a file or directory exists.
#
#  * `os.path.isfile()`: To check if a path refers to a regular file.
#
#  * `os.path.isdir()`: To check if a path refers to a directory.
#
#  * `os.path.basename()`: To get the base name of a path.
#
#  * `os.path.dirname()`: To get the directory name of a path.
#
#  * `os.path.splitext()`: To split a path into root and extension.
#
# * **Directory Operations**:
#
#  * `os.mkdir()`: To create a new directory.
#
#  * `os.makedirs()`: To create directories recursively.
#
#  * `os.rmdir()`: To remove an empty directory.
#
#  * `os.removedirs()`: To remove empty directories recursively.
#
#  * `os.listdir()`: To list the contents of a directory.
#
#  * `os.chdir()`: To change the current working directory.
#
#  * `os.getcwd()`: To get the current working directory.
#
# * **File Operations (beyond basic** `open()` **)**:
#
#  * `os.remove()` / `os.unlink()`: To delete a file.
#
#  * `os.rename()`: To rename a file or directory.
#
#  * `os.stat()`: To get status information about a file (size, modification time, etc.).
#
#  * `os.walk()`: To traverse a directory tree.
#
# While `open()` handles the core reading/writing of file content, the `os` module provides the necessary tools for interacting with the file system itself, managing files and directories, and handling paths in a robust, cross-platform manner.

# %% [markdown]
# ### **23. What are the challenges associated with memory management in Python?**
#
# **Answer**:
#
# Despite Python's automatic memory management, there are still challenges and considerations:
#
# 1. **Reference Cycles**: While the garbage collector addresses circular references, they can still consume memory until the collector runs. In performance-critical applications or those dealing with many short-lived objects, this overhead can be noticeable.
#
# 2. **Memory Footprint for Large Objects**: Python objects inherently have some overhead. For extremely large datasets or objects (e.g., large lists of small integers, or many small strings), the memory footprint can be larger than in lower-level languages like C++.
#
# 3. **Predictability of Garbage Collection**: The exact timing of when the generational garbage collector runs is not always predictable, which can be an issue for real-time systems or applications with strict memory usage constraints.
#
# 4. **Immutable Objects**: Immutable types (like strings, tuples, numbers) create new objects every time they are modified. Frequent operations on large immutable objects can lead to temporary memory spikes.
#
# 5. **Memory Leaks (Indirect)**: While Python prevents true memory leaks in the C sense (where memory is allocated but never freed), "logical" or "indirect" memory leaks can occur. This happens when objects are still referenced (and thus not garbage collected) but are no longer functionally needed by the program (e.g., objects accumulating in a global list that's never cleared).
#
# 6. **Global Interpreter Lock (GIL) and Memory**: While not directly a memory management issue, the GIL can sometimes influence how memory is perceived or managed in multi-threaded scenarios, as only one thread can execute Python bytecode at a time.
#
# 7. **Debugging Memory Issues**: Identifying the root cause of high memory usage or "logical" leaks can be challenging, often requiring specialized profiling tools.
#
# Developers need to be aware of these challenges to write memory-efficient Python code, especially for applications that are memory-intensive or run for long durations.

# %% [markdown]
# ### **24. How do you raise an exception manually in Python?**
#
# **Answer**:
#
# You raise an exception manually in Python using the `raise` keyword, followed by an instance of an exception class.
#
# **Syntax**:

# %%
raise ExceptionType("Optional error message")

# %% [markdown]
# **Examples**:
#
# 1. **Raising a built-in exception**:

# %%
def get_positive_number(value):
    if value < 0:
        raise ValueError("Input must be a positive number.")
    return value

try:
    print(get_positive_number(5))
    print(get_positive_number(-2))
except ValueError as e:
    print(f"Caught an error: {e}")
# Out:
# 5
# Caught an error: Input must be a positive number.

# %% [markdown]
# 2. **Raising a custom exception**:
#
# (First, define your custom exception by inheriting from `Exception` or a more specific built-in exception)

# %%
class MyCustomError(Exception):
    """Custom exception for specific application errors."""
    pass

def check_status(status_code):
    if status_code != 200:
        raise MyCustomError(f"API call failed with status code: {status_code}")
    print("API call successful!")

try:
    check_status(404)
except MyCustomError as e:
    print(f"Custom error caught: {e}")
# Out:
# Custom error caught: API call failed with status code: 404

# %% [markdown]
# When `raise` is executed, the normal flow of the program is interrupted, and Python begins searching for an appropriate `except` block to handle the raised exception. If no matching `except` block is found in the current scope, the exception propagates up the call stack until it's caught or the program terminates.

# %% [markdown]
# ### **25. Why is it important to use multithreading in certain applications?**
#
# **Answer**:
#
# Multithreading is important in certain applications primarily for improving responsiveness and resource utilization, especially for I/O-bound tasks. Here's why:
#
# 1. **Responsiveness (especially in GUIs)**:
#
#  * In graphical user interfaces (GUIs), if a long-running operation (like fetching data from the internet or processing a large file) runs on the main thread, the GUI will "freeze" and become unresponsive.
#
#  * By offloading such operations to a separate thread, the main thread remains free to handle user interactions (button clicks, window resizing), keeping the application responsive.
#
# 2. **I/O-Bound Operations**:
#
#  * Many applications spend a significant amount of time waiting for I/O operations to complete (e.g., reading/writing to disk, network requests, database queries).
#
#  * While one thread is waiting for an I/O operation to finish, other threads can execute useful work. This doesn't involve true parallel execution of CPU-bound code (due to Python's GIL), but it allows the program to "overlap" I/O wait times with CPU computation.
#
#  * This improves overall throughput and perceived performance.
#
# 3. **Simplicity for Concurrent Tasks**:
#
#  * For tasks that logically run concurrently (e.g., a server handling multiple client connections simultaneously), multithreading can simplify the program's design. Each client connection can be handled by a dedicated thread.
#
# 4. **Resource Sharing**:
#
#  * Threads within the same process share the same memory space. This makes data sharing between concurrent tasks relatively straightforward (though requiring careful synchronization to avoid race conditions). This is often simpler than inter-process communication for shared data.
#
#  **Important Note on Python's GIL**: While multithreading is beneficial for I/O-bound tasks in Python, it's crucial to remember the Global Interpreter Lock (GIL). The GIL ensures that only one thread can execute Python bytecode at any given time. This means that for CPU-bound tasks (tasks that primarily involve heavy computation and little I/O), multithreading in Python will not lead to true parallel execution on multi-core processors. For CPU-bound parallelism, multiprocessing is the go-to solution.

# %% [markdown]
# ## **Practical Questions**

# %% [markdown]
# ### **1. How can you open a file for writing in Python and write a string to it?**
#
# **Answer**:
#
# You can open a file for writing using the `open()` function with the `'w'` mode and then use the `write()` method. It's best practice to use a `with` statement to ensure the file is properly closed.

# %%
# Open a file for writing ('w' mode)
# If the file doesn't exist, it will be created.
# If the file exists, its content will be truncated (emptied).
try:
    with open("my_output.txt", "w") as file:
        file.write("Hello, this is a test string.\n")
        file.write("This is a second line.")
    print("Successfully wrote string to 'my_output.txt'")
except IOError as e:
    print(f"Error writing to file: {e}")
# Out:
# Successfully wrote string to 'my_output.txt'

# %% [markdown]
# ### **2. Write a Python program to read the contents of a file and print each line.**
#
# **Answer**:
#
# You can read a file line by line by iterating directly over the file object.

# %%
# Create a dummy file for demonstration
with open("sample_read.txt", "w") as f:
    f.write("First line of text.\n")
    f.write("Second line here.\n")
    f.write("And the last line.")

# Read the contents of the file line by line
try:
    with open("sample_read.txt", "r") as file:
        print("Contents of 'sample_read.txt':")
        for line in file:
            print(line.strip()) # .strip() removes leading/trailing whitespace, including the newline
except FileNotFoundError:
    print("Error: 'sample_read.txt' not found.")
except IOError as e:
    print(f"Error reading file: {e}")
# Out:
# Contents of 'sample_read.txt':
# First line of text.
# Second line here.
# And the last line.

# %% [markdown]
# ### **3. How would you handle a case where the file doesn't exist while trying to open it for reading?**
#
# **Answer**:
#
# You handle a `FileNotFoundError` using a `try-except` block.

# %%
file_name = "non_existent_file.txt"

try:
    with open(file_name, "r") as file:
        content = file.read()
        print(f"File content:\n{content}")
except FileNotFoundError:
    print(f"Error: The file '{file_name}' does not exist.")
except IOError as e:
    print(f"An I/O error occurred: {e}")
# Out:
# Error: The file 'non_existent_file.txt' does not exist.

# %% [markdown]
# ### **4. Write a Python script that reads from one file and writes its content to another file.**
#
# **Answer**:

# %%
source_file = "source.txt"
destination_file = "destination.txt"

# Create a dummy source file
with open(source_file, "w") as f:
    f.write("This is the content from the source file.\n")
    f.write("It will be copied to the destination file.")

try:
    # Open source file for reading
    with open(source_file, "r") as infile:
        content = infile.read()

    # Open destination file for writing (creates/overwrites)
    with open(destination_file, "w") as outfile:
        outfile.write(content)

    print(f"Content successfully copied from '{source_file}' to '{destination_file}'")

except FileNotFoundError:
    print(f"Error: Source file '{source_file}' not found.")
except IOError as e:
    print(f"An I/O error occurred during file operation: {e}")
# Out:
# Content successfully copied from 'source.txt' to 'destination.txt'

# %% [markdown]
# ### **5. How would you catch and handle division by zero error in Python?**
#
# **Answer**:
#
# You use a `try-except` block to catch `ZeroDivisionError`.

# %%
def safe_divide(numerator, denominator):
    try:
        result = numerator / denominator
        print(f"Result of division: {result}")
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")
    except TypeError: # Good practice to catch other potential errors too
        print("Error: Invalid types for division. Please provide numbers.")
    except Exception as e: # Generic catch-all for unexpected errors
        print(f"An unexpected error occurred: {e}")

safe_divide(10, 2)
safe_divide(5, 0)
safe_divide(10, "a") # Demonstrate TypeError handling
# Out:
# Result of division: 5.0
# Error: Cannot divide by zero!
# Error: Invalid types for division. Please provide numbers.

# %% [markdown]
# ### **6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.**
#
# **Answer**:

# %%
import logging

# Configure logging to write ERROR level messages to 'error_log.txt'
logging.basicConfig(filename='error_log.txt', level=logging.ERROR)

try:
    a = 10 / 0  # This will cause a ZeroDivisionError
except ZeroDivisionError:
    # Log an error message when ZeroDivisionError occurs
    logging.error("Tried dividing by zero")
# Out:
# ERROR:root:Tried dividing by zero

# %% [markdown]
# ### **7.How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?**
#
# **Answer**:

# %%
import logging

# Configure logging to process messages from DEBUG level onwards.
# By default, messages go to the console.
logging.basicConfig(level=logging.DEBUG)

# Log messages at different severity levels
logging.info("This is an INFO message")
logging.warning("This is a WARNING message")
logging.error("This is an ERROR message")
# Out:
# WARNING:root:This is a WARNING message
# ERROR:root:This is an ERROR message

# %% [markdown]
# ### **8. Write a program to handle a file opening error using exception handling.**
#
# **Answer**:

# %%
def open_and_read_file(filename):
    try:
        with open(filename, "r") as file:
            content = file.read()
            print(f"Successfully read '{filename}':\n{content}")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except PermissionError:
        print(f"Error: You do not have permission to access '{filename}'.")
    except IOError as e:
        print(f"An unexpected I/O error occurred while opening '{filename}': {e}")
    except Exception as e:
        print(f"An unknown error occurred: {e}")

# Test cases
print("--- Attempting to open an existing file ---")
# Create a dummy file
with open("test_read.txt", "w") as f:
    f.write("This is a test file.")
open_and_read_file("test_read.txt")

print("\n--- Attempting to open a non-existent file ---")
open_and_read_file("non_existent_file.txt")

# On Unix-like systems, you might create a file with restricted permissions for testing PermissionError
# On Windows, PermissionError is less common for simple read attempts but can occur.
# Example: create a file, then change its permissions to read-only for current user
# import os
# os.chmod("test_read.txt", 0o000) # This might cause PermissionError
# print("\n--- Attempting to open a permission-denied file ---")
# open_and_read_file("test_read.txt")
# os.chmod("test_read.txt", 0o600) # Restore permissions
# Out:
# --- Attempting to open an existing file ---
# Successfully read 'test_read.txt':
# This is a test file.
#
# --- Attempting to open a non-existent file ---
# Error: The file 'non_existent_file.txt' was not found.

# %% [markdown]
# ### **9. How can you read a file line by line and store its content in a list in Python?**
#
# **Answer**:

# %%
# Create a dummy file
with open("lines_data.txt", "w") as f:
    f.write("Apple\n")
    f.write("Banana\n")
    f.write("Cherry\n")
    f.write("Date")

file_lines = []
try:
    with open("lines_data.txt", "r") as file:
        for line in file:
            file_lines.append(line.strip()) # .strip() removes the newline character

    print("File content stored in list:")
    print(file_lines)

except FileNotFoundError:
    print("Error: 'lines_data.txt' not found.")
except IOError as e:
    print(f"Error reading file: {e}")
# Out:
# File content stored in list:
# ['Apple', 'Banana', 'Cherry', 'Date']

# %% [markdown]
# ### **10. How can you append data to an existing file in Python?**
#
# **Answer**
#
# You open the file using the `'a'` (append) mode. If the file doesn't exist, it will be created. If it exists, new data is written at the end of the file.

# %%
file_to_append = "my_appended_data.txt"

# Create the file with some initial content if it doesn't exist
with open(file_to_append, "w") as f:
    f.write("Initial line.\n")

print(f"Initial content of '{file_to_append}':")
with open(file_to_append, "r") as f:
    print(f.read())

# Append new data
try:
    with open(file_to_append, "a") as file:
        file.write("This line is appended.\n")
        file.write("Another line added at the end.\n")
    print(f"\nSuccessfully appended data to '{file_to_append}'")

except IOError as e:
    print(f"Error appending to file: {e}")

print(f"\nContent of '{file_to_append}' after appending:")
try:
    with open(file_to_append, "r") as f:
        print(f.read())
except IOError as e:
    print(f"Error reading file after append: {e}")
# Out:
# Initial content of 'my_appended_data.txt':
# Initial line.
#
#
# Successfully appended data to 'my_appended_data.txt'
#
# Content of 'my_appended_data.txt' after appending:
# Initial line.
# This line is appended.
# Another line added at the end.

# %% [markdown]
# ### **11. Write a Python program that uses a `try-except` block to handle an error when attempting to access a dictionary key that doesn't exist?**
#
# **Answer**:
#
# You handle a `KeyError` for non-existent dictionary keys.

# %%
my_dict = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}

def get_dict_value(dictionary, key):
    try:
        value = dictionary[key]
        print(f"The value for key '{key}' is: {value}")
    except KeyError:
        print(f"Error: The key '{key}' does not exist in the dictionary.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

print("--- Accessing existing key ---")
get_dict_value(my_dict, "name")

print("\n--- Accessing non-existent key ---")
get_dict_value(my_dict, "country")

print("\n--- Accessing another existing key ---")
get_dict_value(my_dict, "age")
# Out:
# --- Accessing existing key ---
# The value for key 'name' is: Alice
#
# --- Accessing non-existent key ---
# Error: The key 'country' does not exist in the dictionary.
#
# --- Accessing another existing key ---
# The value for key 'age' is: 30

# %% [markdown]
# ### **12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions?**
#
# **Answer**:

# %%
def perform_operations(data, index_to_access, divisor):
    try:
        # Attempt an operation that might raise IndexError
        element = data[index_to_access]
        print(f"Accessed element at index {index_to_access}: {element}")

        # Attempt an operation that might raise ZeroDivisionError
        result = element / divisor
        print(f"Division result: {result}")

    except IndexError:
        print(f"Error: Invalid index '{index_to_access}'. Index is out of bounds for the list.")
    except ZeroDivisionError:
        print(f"Error: Cannot divide by zero. Divisor provided was {divisor}.")
    except TypeError:
        print(f"Error: A TypeError occurred. Ensure data types are correct for operations.")
    except Exception as e: # Catch any other unexpected exceptions
        print(f"An unexpected error occurred: {type(e).__name__} - {e}")
    finally:
        print("Operation attempt completed.")

print("--- Test Case 1: All operations succeed ---")
perform_operations([1, 2, 3, 4], 2, 2) # Accesses 3, then 3/2 = 1.5

print("\n--- Test Case 2: IndexError ---")
perform_operations([1, 2, 3], 5, 1) # Index 5 is out of bounds

print("\n--- Test Case 3: ZeroDivisionError ---")
perform_operations([10, 20], 0, 0) # Accesses 10, then 10/0

print("\n--- Test Case 4: TypeError (e.g., dividing string) ---")
perform_operations(["abc", "def"], 0, 2) # Accesses "abc", then "abc"/2 (TypeError)
# Out:
# --- Test Case 1: All operations succeed ---
# Accessed element at index 2: 3
# Division result: 1.5
# Operation attempt completed.
#
# --- Test Case 2: IndexError ---
# Error: Invalid index '5'. Index is out of bounds for the list.
# Operation attempt completed.
#
# --- Test Case 3: ZeroDivisionError ---
# Accessed element at index 0: 10
# Error: Cannot divide by zero. Divisor provided was 0.
# Operation attempt completed.
#
# --- Test Case 4: TypeError (e.g., dividing string) ---
# Accessed element at index 0: abc
# Error: A TypeError occurred. Ensure data types are correct for operations.
# Operation attempt completed.

# %% [markdown]
# ### **13. How would you check if a file exists before attempting to read it in Python?**
#
# **Answer**:
#
# You use the `os.path.exists()` function.

# %%
import os

file_to_check = "existing_file.txt"
non_existent_file = "another_non_existent.txt"

# Create a dummy existing file
with open(file_to_check, "w") as f:
    f.write("This file exists.")

if os.path.exists(file_to_check):
    print(f"'{file_to_check}' exists. Attempting to read...")
    try:
        with open(file_to_check, "r") as f:
            print(f.read())
    except IOError as e:
        print(f"Error reading '{file_to_check}': {e}")
else:
    print(f"'{file_to_check}' does not exist.")

print("-" * 30)

if os.path.exists(non_existent_file):
    print(f"'{non_existent_file}' exists. (This should not happen)")
else:
    print(f"'{non_existent_file}' does not exist. Skipping read attempt.")
# Out:
# 'existing_file.txt' exists. Attempting to read...
# This file exists.
# ------------------------------
# 'another_non_existent.txt' does not exist. Skipping read attempt.

# %% [markdown]
# ### **14. Write a program that uses the logging module to log both informational and error messages?**
#
# **Answer**:

# %%
import logging
logging.basicConfig(filename="app.log", level=logging.DEBUG)

logging.info("This is an info message")
logging.error("This is an error message")
# Out:
# ERROR:root:This is an error message

# %% [markdown]
# ### **15. Write a Python program that prints the content of a file and handles the case when the file is empty.**
#
# **Answer**:

# %%
def print_file_content_and_handle_empty(filename):
    try:
        with open(filename, "r") as file:
            content = file.read()
            if not content: # Check if the string is empty
                print(f"The file '{filename}' is empty.")
            else:
                print(f"--- Content of '{filename}' ---")
                print(content)
                print(f"--- End of '{filename}' content ---")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except IOError as e:
        print(f"An I/O error occurred while reading '{filename}': {e}")

# Create a dummy non-empty file
with open("non_empty_file.txt", "w") as f:
    f.write("This file has some content.")

# Create a dummy empty file
with open("empty_file.txt", "w") as f:
    pass # Create an empty file

print_file_content_and_handle_empty("non_empty_file.txt")
print("\n" + "="*40 + "\n")
print_file_content_and_handle_empty("empty_file.txt")
print("\n" + "="*40 + "\n")
print_file_content_and_handle_empty("non_existent_file_for_test.txt")
# Out:
# --- Content of 'non_empty_file.txt' ---
# This file has some content.
# --- End of 'non_empty_file.txt' content ---
#
# ========================================
#
# The file 'empty_file.txt' is empty.
#
# ========================================
#
# Error: The file 'non_existent_file_for_test.txt' was not found.

# %% [markdown]
# ### **16. Demonstrate how to use memory profiling to check the memory usage of a small program.**
#
# **Answer**:
#
# For memory profiling, you'll typically use external libraries like ~memory_profiler`. First, you need to install it:

# %%
pip install memory-profiler
# Out:
# Requirement already satisfied: memory-profiler in /usr/local/lib/python3.11/dist-packages (0.61.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory-profiler) (5.9.5)

# %%
# Save this code as 'memory_test.py'
from memory_profiler import profile
import time

@profile
def create_large_list():
    """
    Creates a large list of integers to demonstrate memory usage.
    """
    print("Creating a list of 10 million integers...")
    my_list = list(range(10_000_000))
    print(f"List size: {len(my_list)} elements.")
    # Keep the list in scope for memory_profiler to track
    # Otherwise, it might be garbage collected too quickly
    time.sleep(1) # Keep it alive briefly for profiling
    del my_list # Explicitly delete to show memory release

@profile
def create_large_string():
    """
    Creates a large string to demonstrate memory usage.
    """
    print("Creating a large string (10MB)...")
    long_string = "A" * (10 * 1024 * 1024) # 10 MB string
    print(f"String length: {len(long_string)} characters.")
    time.sleep(1)
    del long_string

if __name__ == "__main__":
    print("--- Memory Usage Test ---")
    create_large_list()
    print("\n")
    create_large_string()
    print("\n--- Memory Usage Test Complete ---")
# Out:
# --- Memory Usage Test ---
# ERROR: Could not find file /tmp/ipython-input-13-4142508221.py
# Creating a list of 10 million integers...
# List size: 10000000 elements.
#
#
# ERROR: Could not find file /tmp/ipython-input-13-4142508221.py
# Creating a large string (10MB)...
# String length: 10485760 characters.
#
# --- Memory Usage Test Complete ---

# %% [markdown]
# ### **17. Write a Python program to create and write a list of numbers to a file, one number per line.**
#
# **Answer**:

# %%
numbers = [10, 20, 30, 45, 55, 60, 75, 80, 95, 100]
output_file = "numbers_list.txt"

try:
    with open(output_file, "w") as file:
        for number in numbers:
            file.write(str(number) + "\n") # Convert number to string and add newline
    print(f"Successfully wrote numbers to '{output_file}'")

    # Verify content
    print(f"\nContent of '{output_file}':")
    with open(output_file, "r") as file:
        print(file.read())

except IOError as e:
    print(f"Error writing to file: {e}")
# Out:
# Successfully wrote numbers to 'numbers_list.txt'
#
# Content of 'numbers_list.txt':
# 10
# 20
# 30
# 45
# 55
# 60
# 75
# 80
# 95
# 100

# %% [markdown]
# ### **18. How would you implement a basic logging setup that logs to a file with rotation after 1MB.**
#
# **Answer**:

# %%
import logging
from logging.handlers import RotatingFileHandler

# Set up a rotating file handler
# This handler writes logs to a file and rotates them when the file size exceeds a certain limit.
log_handler = RotatingFileHandler(
    filename="my_app.log",        # The name of the log file
    maxBytes=1_000_000,          # Rotate after 1 MB (1,000,000 bytes).
                                 # 1 MB is approximately 10^6 bytes.
    backupCount=3                # Keep 3 backup log files (e.g., my_app.log.1, my_app.log.2, my_app.log.3)
)

# Set logging format
# This defines the structure of each log message.
formatter = logging.Formatter(
    fmt='%(asctime)s - %(levelname)s - %(message)s'
)
# Apply the formatter to the log handler
log_handler.setFormatter(formatter)

# Set up logger
# Get a logger instance, typically by name.
logger = logging.getLogger("MyLogger")
# Set the logging level for this logger. Messages below this level will be ignored.
logger.setLevel(logging.INFO)
# Add the rotating file handler to the logger, so messages are written to the file.
logger.addHandler(log_handler)

# Example log entries
# Generate some log messages to demonstrate the rotation.
for i in range(10000): # Looping to generate enough messages to trigger rotation
    logger.info(f"Log message number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:MyLogger:Log message number 5000
# INFO:MyLogger:Log message number 5001
# INFO:MyLogger:Log message number 5002
# INFO:MyLogger:Log message number 5003
# INFO:MyLogger:Log message number 5004
# INFO:MyLogger:Log message number 5005
# INFO:MyLogger:Log message number 5006
# INFO:MyLogger:Log message number 5007
# INFO:MyLogger:Log message number 5008
# INFO:MyLogger:Log message number 5009
# INFO:MyLogger:Log message number 5010
# INFO:MyLogger:Log message number 5011
# INFO:MyLogger:Log message number 5012
# INFO:MyLogger:Log message number 5013
# INFO:MyLogger:Log message number 5014
# INFO:MyLogger:Log message number 5015
# INFO:MyLogger:Log message number 5016
# INFO:MyLogger:Log message number 5017
# INFO:MyLogger:Log message number 5018
# INFO:MyLogger:Log message number 5019
# INFO:MyLogger:Log message number 5020
# INFO:MyLogger:Log message number 5021
# INFO:MyLogger:Log message number 5022
# INFO:MyLogger:Log message number 5023
# INFO:MyLogger:Log message number 5024
# INFO:MyLogger:Log message number 5025
# INFO:MyLogger:Log message number 5026
# INFO:MyLogger:Log message number 5027
# INFO:MyLogger:Log message number 5028
# INFO:MyLogger:Log message number 5029
# INFO:MyLogger:Log message number 5030
# INFO:MyLogger:Log message number 5031
# INFO:MyLogger:Log message number 5032
# INFO:MyLogger:Log message number 5033
# INFO:MyLogger:Log message number 5034
# INFO:MyLogger:Log message number 5035
# INFO:MyLogger:Log message number 5036
# INFO:MyLogger:Log message number 5037
# INFO:MyLogger:Log message number 5038
# INFO:MyLogger:Log message number 5039
# INFO:MyLogger:Log message number 5040
# INFO:MyLogger:Log message number 5041
# INFO:MyLogger:Log message number 5042
# INFO:MyLogger:Log message number 5043
# INFO:MyLogger:Log message number 5044
# INFO:MyLogger:Log message number 5045
# INFO:MyLogger:Log message number 5046
# INFO:MyLogger:Log message number 5047
# INFO:MyLogger:Log message number 5048
# INFO:MyLogger:Log message number 5049
# INFO:MyLogger:Log message number 5050
# INFO:MyLogger:Log message number 5051
# INFO:MyLogger:Log message number 5052
# INFO:MyLogger:Log message number 5053
# INFO:MyLogger:Log message number 5054
# INFO:MyLogger:Log message number 5055
# INFO:MyLogger:Log message number 5056
# INFO:MyLogger:Log message number 5057
# INFO:MyLogger:Log message number 5058
# INFO:MyLogger:Log message number 5059
# INFO:MyLogger:Log message number 5060
# INFO:MyLogger:Log message number 5061
# INFO:MyLogger:Log message number 5062
# INFO:MyLogger:Log message number 5063
# INFO:MyLogger:Log message number 5064
# INFO:MyLogger:Log message number 5065
# INFO:MyLogger:Log message number 5066
# INFO:MyLogger:Log message number 5067
# INFO:MyLogger:Log message number 5068
# INFO:MyLogger:Log message number 5069
# INFO:MyLogger:Log message number 5070
# INFO:MyLogger:Log message number 5071
# INFO:MyLogger:Log message number 5072
# INFO:MyLogger:Log message number 5073
# INFO:MyLogger:Log message number 5074
# INFO:MyLogger:Log message number 5075
# INFO:MyLogger:Log message number 5076
# INFO:MyLogger:Log message number 5077
# INFO:MyLogger:Log message number 5078
# INFO:MyLogger:Log message number 5079
# INFO:MyLogger:Log message number 5080
# INFO:MyLogger:Log message number 5081
# INFO:MyLogger:Log message number 5082
# INFO:MyLogger:Log message number 5083
# INFO:MyLogger:Log message number 5084
# INFO:MyLogger:Log message number 5085
# INFO:MyLogger:Log message number 5086
# INFO:MyLogger:Log message number 5087
# INFO:MyLogger:Log message number 5088
# INFO:MyLogger:Log message number 5089
# INFO:MyLogger:Log message number 5090
# INFO:MyLogger:Log message number 5091
# INFO:MyLogger:Log message number 5092
# INFO:MyLogger:Log message number 5093
# INFO:MyLogger:Log message number 5094
# INFO:MyLogger:Log message number 5095
# INFO:MyLogger:Log message number 5096
# INFO:MyLogger:Log message number 5097
# INFO:MyLogger:Log message number 5098
# INFO:MyLogger:Log message number 5099
# INFO:MyLogger:Log message number 5100
# INFO:MyLogger:Log message number 5101
# INFO:MyLogger:Log message number 5102
# INFO:MyLogger:Log message number 5103
# INFO:MyLogger:Log message number 5104
# INFO:MyLogger:Log message number 5105
# INFO:MyLogger:Log message number 5106
# INFO:MyLogger:Log message number 5107
# INFO:MyLogger:Log message number 5108
# INFO:MyLogger:Log message number 5109
# INFO:MyLogger:Log message number 5110
# INFO:MyLogger:Log message number 5111
# INFO:MyLogger:Log message number 5112
# INFO:MyLogger:Log message number 5113
# INFO:MyLogger:Log message number 5114
# INFO:MyLogger:Log message number 5115
# INFO:MyLogger:Log message number 5116
# INFO:MyLogger:Log message number 5117
# INFO:MyLogger:Log message number 5118
# INFO:MyLogger:Log message number 5119
# INFO:MyLogger:Log message number 5120
# INFO:MyLogger:Log message number 5121
# INFO:MyLogger:Log message number 5122
# INFO:MyLogger:Log message number 5123
# INFO:MyLogger:Log message number 5124
# INFO:MyLogger:Log message number 5125
# INFO:MyLogger:Log message number 5126
# INFO:MyLogger:Log message number 5127
# INFO:MyLogger:Log message number 5128
# INFO:MyLogger:Log message number 5129
# INFO:MyLogger:Log message number 5130
# INFO:MyLogger:Log message number 5131
# INFO:MyLogger:Log message number 5132
# INFO:MyLogger:Log message number 5133
# INFO:MyLogger:Log message number 5134
# INFO:MyLogger:Log message number 5135
# INFO:MyLogger:Log message number 5136
# INFO:MyLogger:Log message number 5137
# INFO:MyLogger:Log message number 5138
# INFO:MyLogger:Log message number 5139
# INFO:MyLogger:Log message number 5140
# INFO:MyLogger:Log message number 5141
# INFO:MyLogger:Log message number 5142
# INFO:MyLogger:Log message number 5143
# INFO:MyLogger:Log message number 5144
# INFO:MyLogger:Log message number 5145
# INFO:MyLogger:Log message number 5146
# INFO:MyLogger:Log message number 5147
# INFO:MyLogger:Log message number 5148
# INFO:MyLogger:Log message number 5149
# INFO:MyLogger:Log message number 5150
# INFO:MyLogger:Log message number 5151
# INFO:MyLogger:Log message number 5152
# INFO:MyLogger:Log message number 5153
# INFO:MyLogger:Log message number 5154
# INFO:MyLogger:Log message number 5155
# INFO:MyLogger:Log message number 5156
# INFO:MyLogger:Log message number 5157
# INFO:MyLogger:Log message number 5158
# INFO:MyLogger:Log message number 5159
# INFO:MyLogger:Log message number 5160
# INFO:MyLogger:Log message number 5161
# INFO:MyLogger:Log message number 5162
# INFO:MyLogger:Log message number 5163
# INFO:MyLogger:Log message number 5164
# INFO:MyLogger:Log message number 5165
# INFO:MyLogger:Log message number 5166
# INFO:MyLogger:Log message number 5167
# INFO:MyLogger:Log message number 5168
# INFO:MyLogger:Log message number 5169
# INFO:MyLogger:Log message number 5170
# INFO:MyLogger:Log message number 5171
# INFO:MyLogger:Log message number 5172
# INFO:MyLogger:Log message number 5173
# INFO:MyLogger:Log message number 5174
# INFO:MyLogger:Log message number 5175
# INFO:MyLogger:Log message number 5176
# INFO:MyLogger:Log message number 5177
# INFO:MyLogger:Log message number 5178
# INFO:MyLogger:Log message number 5179
# INFO:MyLogger:Log message number 5180
# INFO:MyLogger:Log message number 5181
# INFO:MyLogger:Log message number 5182
# INFO:MyLogger:Log message number 5183
# INFO:MyLogger:Log message number 5184
# INFO:MyLogger:Log message number 5185
# INFO:MyLogger:Log message number 5186
# INFO:MyLogger:Log message number 5187
# INFO:MyLogger:Log message number 5188
# INFO:MyLogger:Log message number 5189
# INFO:MyLogger:Log message number 5190
# INFO:MyLogger:Log message number 5191
# INFO:MyLogger:Log message number 5192
# INFO:MyLogger:Log message number 5193
# INFO:MyLogger:Log message number 5194
# INFO:MyLogger:Log message number 5195
# INFO:MyLogger:Log message number 5196
# INFO:MyLogger:Log message number 5197
# INFO:MyLogger:Log message number 5198
# INFO:MyLogger:Log message number 5199
# INFO:MyLogger:Log message number 5200
# INFO:MyLogger:Log message number 5201
# INFO:MyLogger:Log message number 5202
# INFO:MyLogger:Log message number 5203
# INFO:MyLogger:Log message number 5204
# INFO:MyLogger:Log message number 5205
# INFO:MyLogger:Log message number 5206
# INFO:MyLogger:Log message number 5207
# INFO:MyLogger:Log message number 5208
# INFO:MyLogger:Log message number 5209
# INFO:MyLogger:Log message number 5210
# INFO:MyLogger:Log message number 5211
# INFO:MyLogger:Log message number 5212
# INFO:MyLogger:Log message number 5213
# INFO:MyLogger:Log message number 5214
# INFO:MyLogger:Log message number 5215
# INFO:MyLogger:Log message number 5216
# INFO:MyLogger:Log message number 5217
# INFO:MyLogger:Log message number 5218
# INFO:MyLogger:Log message number 5219
# INFO:MyLogger:Log message number 5220
# INFO:MyLogger:Log message number 5221
# INFO:MyLogger:Log message number 5222
# INFO:MyLogger:Log message number 5223
# INFO:MyLogger:Log message number 5224
# INFO:MyLogger:Log message number 5225
# INFO:MyLogger:Log message number 5226
# INFO:MyLogger:Log message number 5227
# INFO:MyLogger:Log message number 5228
# INFO:MyLogger:Log message number 5229
# INFO:MyLogger:Log message number 5230
# INFO:MyLogger:Log message number 5231
# INFO:MyLogger:Log message number 5232
# INFO:MyLogger:Log message number 5233
# INFO:MyLogger:Log message number 5234
# INFO:MyLogger:Log message number 5235
# INFO:MyLogger:Log message number 5236
# INFO:MyLogger:Log message number 5237
# INFO:MyLogger:Log message number 5238
# INFO:MyLogger:Log message number 5239
# INFO:MyLogger:Log message number 5240
# INFO:MyLogger:Log message number 5241
# INFO:MyLogger:Log message number 5242
# INFO:MyLogger:Log message number 5243
# INFO:MyLogger:Log message number 5244
# INFO:MyLogger:Log message number 5245
# INFO:MyLogger:Log message number 5246
# INFO:MyLogger:Log message number 5247
# INFO:MyLogger:Log message number 5248
# INFO:MyLogger:Log message number 5249
# INFO:MyLogger:Log message number 5250
# INFO:MyLogger:Log message number 5251
# INFO:MyLogger:Log message number 5252
# INFO:MyLogger:Log message number 5253
# INFO:MyLogger:Log message number 5254
# INFO:MyLogger:Log message number 5255
# INFO:MyLogger:Log message number 5256
# INFO:MyLogger:Log message number 5257
# INFO:MyLogger:Log message number 5258
# INFO:MyLogger:Log message number 5259
# INFO:MyLogger:Log message number 5260
# INFO:MyLogger:Log message number 5261
# INFO:MyLogger:Log message number 5262
# INFO:MyLogger:Log message number 5263
# INFO:MyLogger:Log message number 5264
# INFO:MyLogger:Log message number 5265
# INFO:MyLogger:Log message number 5266
# INFO:MyLogger:Log message number 5267
# INFO:MyLogger:Log message number 5268
# INFO:MyLogger:Log message number 5269
# INFO:MyLogger:Log message number 5270
# INFO:MyLogger:Log message number 5271
# INFO:MyLogger:Log message number 5272
# INFO:MyLogger:Log message number 5273
# INFO:MyLogger:Log message number 5274
# INFO:MyLogger:Log message number 5275
# INFO:MyLogger:Log message number 5276
# INFO:MyLogger:Log message number 5277
# INFO:MyLogger:Log message number 5278
# INFO:MyLogger:Log message number 5279
# INFO:MyLogger:Log message number 5280
# INFO:MyLogger:Log message number 5281
# INFO:MyLogger:Log message number 5282
# INFO:MyLogger:Log message number 5283
# INFO:MyLogger:Log message number 5284
# INFO:MyLogger:Log message number 5285
# INFO:MyLogger:Log message number 5286
# INFO:MyLogger:Log message number 5287
# INFO:MyLogger:Log message number 5288
# INFO:MyLogger:Log message number 5289
# INFO:MyLogger:Log message number 5290
# INFO:MyLogger:Log message number 5291
# INFO:MyLogger:Log message number 5292
# INFO:MyLogger:Log message number 5293
# INFO:MyLogger:Log message number 5294
# INFO:MyLogger:Log message number 5295
# INFO:MyLogger:Log message number 5296
# INFO:MyLogger:Log message number 5297
# INFO:MyLogger:Log message number 5298
# INFO:MyLogger:Log message number 5299
# INFO:MyLogger:Log message number 5300
# INFO:MyLogger:Log message number 5301
# INFO:MyLogger:Log message number 5302
# INFO:MyLogger:Log message number 5303
# INFO:MyLogger:Log message number 5304
# INFO:MyLogger:Log message number 5305
# INFO:MyLogger:Log message number 5306
# INFO:MyLogger:Log message number 5307
# INFO:MyLogger:Log message number 5308
# INFO:MyLogger:Log message number 5309
# INFO:MyLogger:Log message number 5310
# INFO:MyLogger:Log message number 5311
# INFO:MyLogger:Log message number 5312
# INFO:MyLogger:Log message number 5313
# INFO:MyLogger:Log message number 5314
# INFO:MyLogger:Log message number 5315
# INFO:MyLogger:Log message number 5316
# INFO:MyLogger:Log message number 5317
# INFO:MyLogger:Log message number 5318
# INFO:MyLogger:Log message number 5319
# INFO:MyLogger:Log message number 5320
# INFO:MyLogger:Log message number 5321
# INFO:MyLogger:Log message number 5322
# INFO:MyLogger:Log message number 5323
# INFO:MyLogger:Log message number 5324
# INFO:MyLogger:Log message number 5325
# INFO:MyLogger:Log message number 5326
# INFO:MyLogger:Log message number 5327
# INFO:MyLogger:Log message number 5328
# INFO:MyLogger:Log message number 5329
# INFO:MyLogger:Log message number 5330
# INFO:MyLogger:Log message number 5331
# INFO:MyLogger:Log message number 5332
# INFO:MyLogger:Log message number 5333
# INFO:MyLogger:Log message number 5334
# INFO:MyLogger:Log message number 5335
# INFO:MyLogger:Log message number 5336
# INFO:MyLogger:Log message number 5337
# INFO:MyLogger:Log message number 5338
# INFO:MyLogger:Log message number 5339
# INFO:MyLogger:Log message number 5340
# INFO:MyLogger:Log message number 5341
# INFO:MyLogger:Log message number 5342
# INFO:MyLogger:Log message number 5343
# INFO:MyLogger:Log message number 5344
# INFO:MyLogger:Log message number 5345
# INFO:MyLogger:Log message number 5346
# INFO:MyLogger:Log message number 5347
# INFO:MyLogger:Log message number 5348
# INFO:MyLogger:Log message number 5349
# INFO:MyLogger:Log message number 5350
# INFO:MyLogger:Log message number 5351
# INFO:MyLogger:Log message number 5352
# INFO:MyLogger:Log message number 5353
# INFO:MyLogger:Log message number 5354
# INFO:MyLogger:Log message number 5355
# INFO:MyLogger:Log message number 5356
# INFO:MyLogger:Log message number 5357
# INFO:MyLogger:Log message number 5358
# INFO:MyLogger:Log message number 5359
# INFO:MyLogger:Log message number 5360
# INFO:MyLogger:Log message number 5361
# INFO:MyLogger:Log message number 5362
# INFO:MyLogger:Log message number 5363
# INFO:MyLogger:Log message number 5364
# INFO:MyLogger:Log message number 5365
# INFO:MyLogger:Log message number 5366
# INFO:MyLogger:Log message number 5367
# INFO:MyLogger:Log message number 5368
# INFO:MyLogger:Log message number 5369
# INFO:MyLogger:Log message number 5370
# INFO:MyLogger:Log message number 5371
# INFO:MyLogger:Log message number 5372
# INFO:MyLogger:Log message number 5373
# INFO:MyLogger:Log message number 5374
# INFO:MyLogger:Log message number 5375
# INFO:MyLogger:Log message number 5376
# INFO:MyLogger:Log message number 5377
# INFO:MyLogger:Log message number 5378
# INFO:MyLogger:Log message number 5379
# INFO:MyLogger:Log message number 5380
# INFO:MyLogger:Log message number 5381
# INFO:MyLogger:Log message number 5382
# INFO:MyLogger:Log message number 5383
# INFO:MyLogger:Log message number 5384
# INFO:MyLogger:Log message number 5385
# INFO:MyLogger:Log message number 5386
# INFO:MyLogger:Log message number 5387
# INFO:MyLogger:Log message number 5388
# INFO:MyLogger:Log message number 5389
# INFO:MyLogger:Log message number 5390
# INFO:MyLogger:Log message number 5391
# INFO:MyLogger:Log message number 5392
# INFO:MyLogger:Log message number 5393
# INFO:MyLogger:Log message number 5394
# INFO:MyLogger:Log message number 5395
# INFO:MyLogger:Log message number 5396
# INFO:MyLogger:Log message number 5397
# INFO:MyLogger:Log message number 5398
# INFO:MyLogger:Log message number 5399
# INFO:MyLogger:Log message number 5400
# INFO:MyLogger:Log message number 5401
# INFO:MyLogger:Log message number 5402
# INFO:MyLogger:Log message number 5403
# INFO:MyLogger:Log message number 5404
# INFO:MyLogger:Log message number 5405
# INFO:MyLogger:Log message number 5406
# INFO:MyLogger:Log message number 5407
# INFO:MyLogger:Log message number 5408
# INFO:MyLogger:Log message number 5409
# INFO:MyLogger:Log message number 5410
# INFO:MyLogger:Log message number 5411
# INFO:MyLogger:Log message number 5412
# INFO:MyLogger:Log message number 5413
# INFO:MyLogger:Log message number 5414
# INFO:MyLogger:Log message number 5415
# INFO:MyLogger:Log message number 5416
# INFO:MyLogger:Log message number 5417
# INFO:MyLogger:Log message number 5418
# INFO:MyLogger:Log message number 5419
# INFO:MyLogger:Log message number 5420
# INFO:MyLogger:Log message number 5421
# INFO:MyLogger:Log message number 5422
# INFO:MyLogger:Log message number 5423
# INFO:MyLogger:Log message number 5424
# INFO:MyLogger:Log message number 5425
# INFO:MyLogger:Log message number 5426
# INFO:MyLogger:Log message number 5427
# INFO:MyLogger:Log message number 5428
# INFO:MyLogger:Log message number 5429
# INFO:MyLogger:Log message number 5430
# INFO:MyLogger:Log message number 5431
# INFO:MyLogger:Log message number 5432
# INFO:MyLogger:Log message number 5433
# INFO:MyLogger:Log message number 5434
# INFO:MyLogger:Log message number 5435
# INFO:MyLogger:Log message number 5436
# INFO:MyLogger:Log message number 5437
# INFO:MyLogger:Log message number 5438
# INFO:MyLogger:Log message number 5439
# INFO:MyLogger:Log message number 5440
# INFO:MyLogger:Log message number 5441
# INFO:MyLogger:Log message number 5442
# INFO:MyLogger:Log message number 5443
# INFO:MyLogger:Log message number 5444
# INFO:MyLogger:Log message number 5445
# INFO:MyLogger:Log message number 5446
# INFO:MyLogger:Log message number 5447
# INFO:MyLogger:Log message number 5448
# INFO:MyLogger:Log message number 5449
# INFO:MyLogger:Log message number 5450
# INFO:MyLogger:Log message number 5451
# INFO:MyLogger:Log message number 5452
# INFO:MyLogger:Log message number 5453
# INFO:MyLogger:Log message number 5454
# INFO:MyLogger:Log message number 5455
# INFO:MyLogger:Log message number 5456
# INFO:MyLogger:Log message number 5457
# INFO:MyLogger:Log message number 5458
# INFO:MyLogger:Log message number 5459
# INFO:MyLogger:Log message number 5460
# INFO:MyLogger:Log message number 5461
# INFO:MyLogger:Log message number 5462
# INFO:MyLogger:Log message number 5463
# INFO:MyLogger:Log message number 5464
# INFO:MyLogger:Log message number 5465
# INFO:MyLogger:Log message number 5466
# INFO:MyLogger:Log message number 5467
# INFO:MyLogger:Log message number 5468
# INFO:MyLogger:Log message number 5469
# INFO:MyLogger:Log message number 5470
# INFO:MyLogger:Log message number 5471
# INFO:MyLogger:Log message number 5472
# INFO:MyLogger:Log message number 5473
# INFO:MyLogger:Log message number 5474
# INFO:MyLogger:Log message number 5475
# INFO:MyLogger:Log message number 5476
# INFO:MyLogger:Log message number 5477
# INFO:MyLogger:Log message number 5478
# INFO:MyLogger:Log message number 5479
# INFO:MyLogger:Log message number 5480
# INFO:MyLogger:Log message number 5481
# INFO:MyLogger:Log message number 5482
# INFO:MyLogger:Log message number 5483
# INFO:MyLogger:Log message number 5484
# INFO:MyLogger:Log message number 5485
# INFO:MyLogger:Log message number 5486
# INFO:MyLogger:Log message number 5487
# INFO:MyLogger:Log message number 5488
# INFO:MyLogger:Log message number 5489
# INFO:MyLogger:Log message number 5490
# INFO:MyLogger:Log message number 5491
# INFO:MyLogger:Log message number 5492
# INFO:MyLogger:Log message number 5493
# INFO:MyLogger:Log message number 5494
# INFO:MyLogger:Log message number 5495
# INFO:MyLogger:Log message number 5496
# INFO:MyLogger:Log message number 5497
# INFO:MyLogger:Log message number 5498
# INFO:MyLogger:Log message number 5499
# INFO:MyLogger:Log message number 5500
# INFO:MyLogger:Log message number 5501
# INFO:MyLogger:Log message number 5502
# INFO:MyLogger:Log message number 5503
# INFO:MyLogger:Log message number 5504
# INFO:MyLogger:Log message number 5505
# INFO:MyLogger:Log message number 5506
# INFO:MyLogger:Log message number 5507
# INFO:MyLogger:Log message number 5508
# INFO:MyLogger:Log message number 5509
# INFO:MyLogger:Log message number 5510
# INFO:MyLogger:Log message number 5511
# INFO:MyLogger:Log message number 5512
# INFO:MyLogger:Log message number 5513
# INFO:MyLogger:Log message number 5514
# INFO:MyLogger:Log message number 5515
# INFO:MyLogger:Log message number 5516
# INFO:MyLogger:Log message number 5517
# INFO:MyLogger:Log message number 5518
# INFO:MyLogger:Log message number 5519
# INFO:MyLogger:Log message number 5520
# INFO:MyLogger:Log message number 5521
# INFO:MyLogger:Log message number 5522
# INFO:MyLogger:Log message number 5523
# INFO:MyLogger:Log message number 5524
# INFO:MyLogger:Log message number 5525
# INFO:MyLogger:Log message number 5526
# INFO:MyLogger:Log message number 5527
# INFO:MyLogger:Log message number 5528
# INFO:MyLogger:Log message number 5529
# INFO:MyLogger:Log message number 5530
# INFO:MyLogger:Log message number 5531
# INFO:MyLogger:Log message number 5532
# INFO:MyLogger:Log message number 5533
# INFO:MyLogger:Log message number 5534
# INFO:MyLogger:Log message number 5535
# INFO:MyLogger:Log message number 5536
# INFO:MyLogger:Log message number 5537
# INFO:MyLogger:Log message number 5538
# INFO:MyLogger:Log message number 5539
# INFO:MyLogger:Log message number 5540
# INFO:MyLogger:Log message number 5541
# INFO:MyLogger:Log message number 5542
# INFO:MyLogger:Log message number 5543
# INFO:MyLogger:Log message number 5544
# INFO:MyLogger:Log message number 5545
# INFO:MyLogger:Log message number 5546
# INFO:MyLogger:Log message number 5547
# INFO:MyLogger:Log message number 5548
# INFO:MyLogger:Log message number 5549
# INFO:MyLogger:Log message number 5550
# INFO:MyLogger:Log message number 5551
# INFO:MyLogger:Log message number 5552
# INFO:MyLogger:Log message number 5553
# INFO:MyLogger:Log message number 5554
# INFO:MyLogger:Log message number 5555
# INFO:MyLogger:Log message number 5556
# INFO:MyLogger:Log message number 5557
# INFO:MyLogger:Log message number 5558
# INFO:MyLogger:Log message number 5559
# INFO:MyLogger:Log message number 5560
# INFO:MyLogger:Log message number 5561
# INFO:MyLogger:Log message number 5562
# INFO:MyLogger:Log message number 5563
# INFO:MyLogger:Log message number 5564
# INFO:MyLogger:Log message number 5565
# INFO:MyLogger:Log message number 5566
# INFO:MyLogger:Log message number 5567
# INFO:MyLogger:Log message number 5568
# INFO:MyLogger:Log message number 5569
# INFO:MyLogger:Log message number 5570
# INFO:MyLogger:Log message number 5571
# INFO:MyLogger:Log message number 5572
# INFO:MyLogger:Log message number 5573
# INFO:MyLogger:Log message number 5574
# INFO:MyLogger:Log message number 5575
# INFO:MyLogger:Log message number 5576
# INFO:MyLogger:Log message number 5577
# INFO:MyLogger:Log message number 5578
# INFO:MyLogger:Log message number 5579
# INFO:MyLogger:Log message number 5580
# INFO:MyLogger:Log message number 5581
# INFO:MyLogger:Log message number 5582
# INFO:MyLogger:Log message number 5583
# INFO:MyLogger:Log message number 5584
# INFO:MyLogger:Log message number 5585
# INFO:MyLogger:Log message number 5586
# INFO:MyLogger:Log message number 5587
# INFO:MyLogger:Log message number 5588
# INFO:MyLogger:Log message number 5589
# INFO:MyLogger:Log message number 5590
# INFO:MyLogger:Log message number 5591
# INFO:MyLogger:Log message number 5592
# INFO:MyLogger:Log message number 5593
# INFO:MyLogger:Log message number 5594
# INFO:MyLogger:Log message number 5595
# INFO:MyLogger:Log message number 5596
# INFO:MyLogger:Log message number 5597
# INFO:MyLogger:Log message number 5598
# INFO:MyLogger:Log message number 5599
# INFO:MyLogger:Log message number 5600
# INFO:MyLogger:Log message number 5601
# INFO:MyLogger:Log message number 5602
# INFO:MyLogger:Log message number 5603
# INFO:MyLogger:Log message number 5604
# INFO:MyLogger:Log message number 5605
# INFO:MyLogger:Log message number 5606
# INFO:MyLogger:Log message number 5607
# INFO:MyLogger:Log message number 5608
# INFO:MyLogger:Log message number 5609
# INFO:MyLogger:Log message number 5610
# INFO:MyLogger:Log message number 5611
# INFO:MyLogger:Log message number 5612
# INFO:MyLogger:Log message number 5613
# INFO:MyLogger:Log message number 5614
# INFO:MyLogger:Log message number 5615
# INFO:MyLogger:Log message number 5616
# INFO:MyLogger:Log message number 5617
# INFO:MyLogger:Log message number 5618
# INFO:MyLogger:Log message number 5619
# INFO:MyLogger:Log message number 5620
# INFO:MyLogger:Log message number 5621
# INFO:MyLogger:Log message number 5622
# INFO:MyLogger:Log message number 5623
# INFO:MyLogger:Log message number 5624
# INFO:MyLogger:Log message number 5625
# INFO:MyLogger:Log message number 5626
# INFO:MyLogger:Log message number 5627
# INFO:MyLogger:Log message number 5628
# INFO:MyLogger:Log message number 5629
# INFO:MyLogger:Log message number 5630
# INFO:MyLogger:Log message number 5631
# INFO:MyLogger:Log message number 5632
# INFO:MyLogger:Log message number 5633
# INFO:MyLogger:Log message number 5634
# INFO:MyLogger:Log message number 5635
# INFO:MyLogger:Log message number 5636
# INFO:MyLogger:Log message number 5637
# INFO:MyLogger:Log message number 5638
# INFO:MyLogger:Log message number 5639
# INFO:MyLogger:Log message number 5640
# INFO:MyLogger:Log message number 5641
# INFO:MyLogger:Log message number 5642
# INFO:MyLogger:Log message number 5643
# INFO:MyLogger:Log message number 5644
# INFO:MyLogger:Log message number 5645
# INFO:MyLogger:Log message number 5646
# INFO:MyLogger:Log message number 5647
# INFO:MyLogger:Log message number 5648
# INFO:MyLogger:Log message number 5649
# INFO:MyLogger:Log message number 5650
# INFO:MyLogger:Log message number 5651
# INFO:MyLogger:Log message number 5652
# INFO:MyLogger:Log message number 5653
# INFO:MyLogger:Log message number 5654
# INFO:MyLogger:Log message number 5655
# INFO:MyLogger:Log message number 5656
# INFO:MyLogger:Log message number 5657
# INFO:MyLogger:Log message number 5658
# INFO:MyLogger:Log message number 5659
# INFO:MyLogger:Log message number 5660
# INFO:MyLogger:Log message number 5661
# INFO:MyLogger:Log message number 5662
# INFO:MyLogger:Log message number 5663
# INFO:MyLogger:Log message number 5664
# INFO:MyLogger:Log message number 5665
# INFO:MyLogger:Log message number 5666
# INFO:MyLogger:Log message number 5667
# INFO:MyLogger:Log message number 5668
# INFO:MyLogger:Log message number 5669
# INFO:MyLogger:Log message number 5670
# INFO:MyLogger:Log message number 5671
# INFO:MyLogger:Log message number 5672
# INFO:MyLogger:Log message number 5673
# INFO:MyLogger:Log message number 5674
# INFO:MyLogger:Log message number 5675
# INFO:MyLogger:Log message number 5676
# INFO:MyLogger:Log message number 5677
# INFO:MyLogger:Log message number 5678
# INFO:MyLogger:Log message number 5679
# INFO:MyLogger:Log message number 5680
# INFO:MyLogger:Log message number 5681
# INFO:MyLogger:Log message number 5682
# INFO:MyLogger:Log message number 5683
# INFO:MyLogger:Log message number 5684
# INFO:MyLogger:Log message number 5685
# INFO:MyLogger:Log message number 5686
# INFO:MyLogger:Log message number 5687
# INFO:MyLogger:Log message number 5688
# INFO:MyLogger:Log message number 5689
# INFO:MyLogger:Log message number 5690
# INFO:MyLogger:Log message number 5691
# INFO:MyLogger:Log message number 5692
# INFO:MyLogger:Log message number 5693
# INFO:MyLogger:Log message number 5694
# INFO:MyLogger:Log message number 5695
# INFO:MyLogger:Log message number 5696
# INFO:MyLogger:Log message number 5697
# INFO:MyLogger:Log message number 5698
# INFO:MyLogger:Log message number 5699
# INFO:MyLogger:Log message number 5700
# INFO:MyLogger:Log message number 5701
# INFO:MyLogger:Log message number 5702
# INFO:MyLogger:Log message number 5703
# INFO:MyLogger:Log message number 5704
# INFO:MyLogger:Log message number 5705
# INFO:MyLogger:Log message number 5706
# INFO:MyLogger:Log message number 5707
# INFO:MyLogger:Log message number 5708
# INFO:MyLogger:Log message number 5709
# INFO:MyLogger:Log message number 5710
# INFO:MyLogger:Log message number 5711
# INFO:MyLogger:Log message number 5712
# INFO:MyLogger:Log message number 5713
# INFO:MyLogger:Log message number 5714
# INFO:MyLogger:Log message number 5715
# INFO:MyLogger:Log message number 5716
# INFO:MyLogger:Log message number 5717
# INFO:MyLogger:Log message number 5718
# INFO:MyLogger:Log message number 5719
# INFO:MyLogger:Log message number 5720
# INFO:MyLogger:Log message number 5721
# INFO:MyLogger:Log message number 5722
# INFO:MyLogger:Log message number 5723
# INFO:MyLogger:Log message number 5724
# INFO:MyLogger:Log message number 5725
# INFO:MyLogger:Log message number 5726
# INFO:MyLogger:Log message number 5727
# INFO:MyLogger:Log message number 5728
# INFO:MyLogger:Log message number 5729
# INFO:MyLogger:Log message number 5730
# INFO:MyLogger:Log message number 5731
# INFO:MyLogger:Log message number 5732
# INFO:MyLogger:Log message number 5733
# INFO:MyLogger:Log message number 5734
# INFO:MyLogger:Log message number 5735
# INFO:MyLogger:Log message number 5736
# INFO:MyLogger:Log message number 5737
# INFO:MyLogger:Log message number 5738
# INFO:MyLogger:Log message number 5739
# INFO:MyLogger:Log message number 5740
# INFO:MyLogger:Log message number 5741
# INFO:MyLogger:Log message number 5742
# INFO:MyLogger:Log message number 5743
# INFO:MyLogger:Log message number 5744
# INFO:MyLogger:Log message number 5745
# INFO:MyLogger:Log message number 5746
# INFO:MyLogger:Log message number 5747
# INFO:MyLogger:Log message number 5748
# INFO:MyLogger:Log message number 5749
# INFO:MyLogger:Log message number 5750
# INFO:MyLogger:Log message number 5751
# INFO:MyLogger:Log message number 5752
# INFO:MyLogger:Log message number 5753
# INFO:MyLogger:Log message number 5754
# INFO:MyLogger:Log message number 5755
# INFO:MyLogger:Log message number 5756
# INFO:MyLogger:Log message number 5757
# INFO:MyLogger:Log message number 5758
# INFO:MyLogger:Log message number 5759
# INFO:MyLogger:Log message number 5760
# INFO:MyLogger:Log message number 5761
# INFO:MyLogger:Log message number 5762
# INFO:MyLogger:Log message number 5763
# INFO:MyLogger:Log message number 5764
# INFO:MyLogger:Log message number 5765
# INFO:MyLogger:Log message number 5766
# INFO:MyLogger:Log message number 5767
# INFO:MyLogger:Log message number 5768
# INFO:MyLogger:Log message number 5769
# INFO:MyLogger:Log message number 5770
# INFO:MyLogger:Log message number 5771
# INFO:MyLogger:Log message number 5772
# INFO:MyLogger:Log message number 5773
# INFO:MyLogger:Log message number 5774
# INFO:MyLogger:Log message number 5775
# INFO:MyLogger:Log message number 5776
# INFO:MyLogger:Log message number 5777
# INFO:MyLogger:Log message number 5778
# INFO:MyLogger:Log message number 5779
# INFO:MyLogger:Log message number 5780
# INFO:MyLogger:Log message number 5781
# INFO:MyLogger:Log message number 5782
# INFO:MyLogger:Log message number 5783
# INFO:MyLogger:Log message number 5784
# INFO:MyLogger:Log message number 5785
# INFO:MyLogger:Log message number 5786
# INFO:MyLogger:Log message number 5787
# INFO:MyLogger:Log message number 5788
# INFO:MyLogger:Log message number 5789
# INFO:MyLogger:Log message number 5790
# INFO:MyLogger:Log message number 5791
# INFO:MyLogger:Log message number 5792
# INFO:MyLogger:Log message number 5793
# INFO:MyLogger:Log message number 5794
# INFO:MyLogger:Log message number 5795
# INFO:MyLogger:Log message number 5796
# INFO:MyLogger:Log message number 5797
# INFO:MyLogger:Log message number 5798
# INFO:MyLogger:Log message number 5799
# INFO:MyLogger:Log message number 5800
# INFO:MyLogger:Log message number 5801
# INFO:MyLogger:Log message number 5802
# INFO:MyLogger:Log message number 5803
# INFO:MyLogger:Log message number 5804
# INFO:MyLogger:Log message number 5805
# INFO:MyLogger:Log message number 5806
# INFO:MyLogger:Log message number 5807
# INFO:MyLogger:Log message number 5808
# INFO:MyLogger:Log message number 5809
# INFO:MyLogger:Log message number 5810
# INFO:MyLogger:Log message number 5811
# INFO:MyLogger:Log message number 5812
# INFO:MyLogger:Log message number 5813
# INFO:MyLogger:Log message number 5814
# INFO:MyLogger:Log message number 5815
# INFO:MyLogger:Log message number 5816
# INFO:MyLogger:Log message number 5817
# INFO:MyLogger:Log message number 5818
# INFO:MyLogger:Log message number 5819
# INFO:MyLogger:Log message number 5820
# INFO:MyLogger:Log message number 5821
# INFO:MyLogger:Log message number 5822
# INFO:MyLogger:Log message number 5823
# INFO:MyLogger:Log message number 5824
# INFO:MyLogger:Log message number 5825
# INFO:MyLogger:Log message number 5826
# INFO:MyLogger:Log message number 5827
# INFO:MyLogger:Log message number 5828
# INFO:MyLogger:Log message number 5829
# INFO:MyLogger:Log message number 5830
# INFO:MyLogger:Log message number 5831
# INFO:MyLogger:Log message number 5832
# INFO:MyLogger:Log message number 5833
# INFO:MyLogger:Log message number 5834
# INFO:MyLogger:Log message number 5835
# INFO:MyLogger:Log message number 5836
# INFO:MyLogger:Log message number 5837
# INFO:MyLogger:Log message number 5838
# INFO:MyLogger:Log message number 5839
# INFO:MyLogger:Log message number 5840
# INFO:MyLogger:Log message number 5841
# INFO:MyLogger:Log message number 5842
# INFO:MyLogger:Log message number 5843
# INFO:MyLogger:Log message number 5844
# INFO:MyLogger:Log message number 5845
# INFO:MyLogger:Log message number 5846
# INFO:MyLogger:Log message number 5847
# INFO:MyLogger:Log message number 5848
# INFO:MyLogger:Log message number 5849
# INFO:MyLogger:Log message number 5850
# INFO:MyLogger:Log message number 5851
# INFO:MyLogger:Log message number 5852
# INFO:MyLogger:Log message number 5853
# INFO:MyLogger:Log message number 5854
# INFO:MyLogger:Log message number 5855
# INFO:MyLogger:Log message number 5856
# INFO:MyLogger:Log message number 5857
# INFO:MyLogger:Log message number 5858
# INFO:MyLogger:Log message number 5859
# INFO:MyLogger:Log message number 5860
# INFO:MyLogger:Log message number 5861
# INFO:MyLogger:Log message number 5862
# INFO:MyLogger:Log message number 5863
# INFO:MyLogger:Log message number 5864
# INFO:MyLogger:Log message number 5865
# INFO:MyLogger:Log message number 5866
# INFO:MyLogger:Log message number 5867
# INFO:MyLogger:Log message number 5868
# INFO:MyLogger:Log message number 5869
# INFO:MyLogger:Log message number 5870
# INFO:MyLogger:Log message number 5871
# INFO:MyLogger:Log message number 5872
# INFO:MyLogger:Log message number 5873
# INFO:MyLogger:Log message number 5874
# INFO:MyLogger:Log message number 5875
# INFO:MyLogger:Log message number 5876
# INFO:MyLogger:Log message number 5877
# INFO:MyLogger:Log message number 5878
# INFO:MyLogger:Log message number 5879
# INFO:MyLogger:Log message number 5880
# INFO:MyLogger:Log message number 5881
# INFO:MyLogger:Log message number 5882
# INFO:MyLogger:Log message number 5883
# INFO:MyLogger:Log message number 5884
# INFO:MyLogger:Log message number 5885
# INFO:MyLogger:Log message number 5886
# INFO:MyLogger:Log message number 5887
# INFO:MyLogger:Log message number 5888
# INFO:MyLogger:Log message number 5889
# INFO:MyLogger:Log message number 5890
# INFO:MyLogger:Log message number 5891
# INFO:MyLogger:Log message number 5892
# INFO:MyLogger:Log message number 5893
# INFO:MyLogger:Log message number 5894
# INFO:MyLogger:Log message number 5895
# INFO:MyLogger:Log message number 5896
# INFO:MyLogger:Log message number 5897
# INFO:MyLogger:Log message number 5898
# INFO:MyLogger:Log message number 5899
# INFO:MyLogger:Log message number 5900
# INFO:MyLogger:Log message number 5901
# INFO:MyLogger:Log message number 5902
# INFO:MyLogger:Log message number 5903
# INFO:MyLogger:Log message number 5904
# INFO:MyLogger:Log message number 5905
# INFO:MyLogger:Log message number 5906
# INFO:MyLogger:Log message number 5907
# INFO:MyLogger:Log message number 5908
# INFO:MyLogger:Log message number 5909
# INFO:MyLogger:Log message number 5910
# INFO:MyLogger:Log message number 5911
# INFO:MyLogger:Log message number 5912
# INFO:MyLogger:Log message number 5913
# INFO:MyLogger:Log message number 5914
# INFO:MyLogger:Log message number 5915
# INFO:MyLogger:Log message number 5916
# INFO:MyLogger:Log message number 5917
# INFO:MyLogger:Log message number 5918
# INFO:MyLogger:Log message number 5919
# INFO:MyLogger:Log message number 5920
# INFO:MyLogger:Log message number 5921
# INFO:MyLogger:Log message number 5922
# INFO:MyLogger:Log message number 5923
# INFO:MyLogger:Log message number 5924
# INFO:MyLogger:Log message number 5925
# INFO:MyLogger:Log message number 5926
# INFO:MyLogger:Log message number 5927
# INFO:MyLogger:Log message number 5928
# INFO:MyLogger:Log message number 5929
# INFO:MyLogger:Log message number 5930
# INFO:MyLogger:Log message number 5931
# INFO:MyLogger:Log message number 5932
# INFO:MyLogger:Log message number 5933
# INFO:MyLogger:Log message number 5934
# INFO:MyLogger:Log message number 5935
# INFO:MyLogger:Log message number 5936
# INFO:MyLogger:Log message number 5937
# INFO:MyLogger:Log message number 5938
# INFO:MyLogger:Log message number 5939
# INFO:MyLogger:Log message number 5940
# INFO:MyLogger:Log message number 5941
# INFO:MyLogger:Log message number 5942
# INFO:MyLogger:Log message number 5943
# INFO:MyLogger:Log message number 5944
# INFO:MyLogger:Log message number 5945
# INFO:MyLogger:Log message number 5946
# INFO:MyLogger:Log message number 5947
# INFO:MyLogger:Log message number 5948
# INFO:MyLogger:Log message number 5949
# INFO:MyLogger:Log message number 5950
# INFO:MyLogger:Log message number 5951
# INFO:MyLogger:Log message number 5952
# INFO:MyLogger:Log message number 5953
# INFO:MyLogger:Log message number 5954
# INFO:MyLogger:Log message number 5955
# INFO:MyLogger:Log message number 5956
# INFO:MyLogger:Log message number 5957
# INFO:MyLogger:Log message number 5958
# INFO:MyLogger:Log message number 5959
# INFO:MyLogger:Log message number 5960
# INFO:MyLogger:Log message number 5961
# INFO:MyLogger:Log message number 5962
# INFO:MyLogger:Log message number 5963
# INFO:MyLogger:Log message number 5964
# INFO:MyLogger:Log message number 5965
# INFO:MyLogger:Log message number 5966
# INFO:MyLogger:Log message number 5967
# INFO:MyLogger:Log message number 5968
# INFO:MyLogger:Log message number 5969
# INFO:MyLogger:Log message number 5970
# INFO:MyLogger:Log message number 5971
# INFO:MyLogger:Log message number 5972
# INFO:MyLogger:Log message number 5973
# INFO:MyLogger:Log message number 5974
# INFO:MyLogger:Log message number 5975
# INFO:MyLogger:Log message number 5976
# INFO:MyLogger:Log message number 5977
# INFO:MyLogger:Log message number 5978
# INFO:MyLogger:Log message number 5979
# INFO:MyLogger:Log message number 5980
# INFO:MyLogger:Log message number 5981
# INFO:MyLogger:Log message number 5982
# INFO:MyLogger:Log message number 5983
# INFO:MyLogger:Log message number 5984
# INFO:MyLogger:Log message number 5985
# INFO:MyLogger:Log message number 5986
# INFO:MyLogger:Log message number 5987
# INFO:MyLogger:Log message number 5988
# INFO:MyLogger:Log message number 5989
# INFO:MyLogger:Log message number 5990
# INFO:MyLogger:Log message number 5991
# INFO:MyLogger:Log message number 5992
# INFO:MyLogger:Log message number 5993
# INFO:MyLogger:Log message number 5994
# INFO:MyLogger:Log message number 5995
# INFO:MyLogger:Log message number 5996
# INFO:MyLogger:Log message number 5997
# INFO:MyLogger:Log message number 5998
# INFO:MyLogger:Log message number 5999
# INFO:MyLogger:Log message number 6000
# INFO:MyLogger:Log message number 6001
# INFO:MyLogger:Log message number 6002
# INFO:MyLogger:Log message number 6003
# INFO:MyLogger:Log message number 6004
# INFO:MyLogger:Log message number 6005
# INFO:MyLogger:Log message number 6006
# INFO:MyLogger:Log message number 6007
# INFO:MyLogger:Log message number 6008
# INFO:MyLogger:Log message number 6009
# INFO:MyLogger:Log message number 6010
# INFO:MyLogger:Log message number 6011
# INFO:MyLogger:Log message number 6012
# INFO:MyLogger:Log message number 6013
# INFO:MyLogger:Log message number 6014
# INFO:MyLogger:Log message number 6015
# INFO:MyLogger:Log message number 6016
# INFO:MyLogger:Log message number 6017
# INFO:MyLogger:Log message number 6018
# INFO:MyLogger:Log message number 6019
# INFO:MyLogger:Log message number 6020
# INFO:MyLogger:Log message number 6021
# INFO:MyLogger:Log message number 6022
# INFO:MyLogger:Log message number 6023
# INFO:MyLogger:Log message number 6024
# INFO:MyLogger:Log message number 6025
# INFO:MyLogger:Log message number 6026
# INFO:MyLogger:Log message number 6027
# INFO:MyLogger:Log message number 6028
# INFO:MyLogger:Log message number 6029
# INFO:MyLogger:Log message number 6030
# INFO:MyLogger:Log message number 6031
# INFO:MyLogger:Log message number 6032
# INFO:MyLogger:Log message number 6033
# INFO:MyLogger:Log message number 6034
# INFO:MyLogger:Log message number 6035
# INFO:MyLogger:Log message number 6036
# INFO:MyLogger:Log message number 6037
# INFO:MyLogger:Log message number 6038
# INFO:MyLogger:Log message number 6039
# INFO:MyLogger:Log message number 6040
# INFO:MyLogger:Log message number 6041
# INFO:MyLogger:Log message number 6042
# INFO:MyLogger:Log message number 6043
# INFO:MyLogger:Log message number 6044
# INFO:MyLogger:Log message number 6045
# INFO:MyLogger:Log message number 6046
# INFO:MyLogger:Log message number 6047
# INFO:MyLogger:Log message number 6048
# INFO:MyLogger:Log message number 6049
# INFO:MyLogger:Log message number 6050
# INFO:MyLogger:Log message number 6051
# INFO:MyLogger:Log message number 6052
# INFO:MyLogger:Log message number 6053
# INFO:MyLogger:Log message number 6054
# INFO:MyLogger:Log message number 6055
# INFO:MyLogger:Log message number 6056
# INFO:MyLogger:Log message number 6057
# INFO:MyLogger:Log message number 6058
# INFO:MyLogger:Log message number 6059
# INFO:MyLogger:Log message number 6060
# INFO:MyLogger:Log message number 6061
# INFO:MyLogger:Log message number 6062
# INFO:MyLogger:Log message number 6063
# INFO:MyLogger:Log message number 6064
# INFO:MyLogger:Log message number 6065
# INFO:MyLogger:Log message number 6066
# INFO:MyLogger:Log message number 6067
# INFO:MyLogger:Log message number 6068
# INFO:MyLogger:Log message number 6069
# INFO:MyLogger:Log message number 6070
# INFO:MyLogger:Log message number 6071
# INFO:MyLogger:Log message number 6072
# INFO:MyLogger:Log message number 6073
# INFO:MyLogger:Log message number 6074
# INFO:MyLogger:Log message number 6075
# INFO:MyLogger:Log message number 6076
# INFO:MyLogger:Log message number 6077
# INFO:MyLogger:Log message number 6078
# INFO:MyLogger:Log message number 6079
# INFO:MyLogger:Log message number 6080
# INFO:MyLogger:Log message number 6081
# INFO:MyLogger:Log message number 6082
# INFO:MyLogger:Log message number 6083
# INFO:MyLogger:Log message number 6084
# INFO:MyLogger:Log message number 6085
# INFO:MyLogger:Log message number 6086
# INFO:MyLogger:Log message number 6087
# INFO:MyLogger:Log message number 6088
# INFO:MyLogger:Log message number 6089
# INFO:MyLogger:Log message number 6090
# INFO:MyLogger:Log message number 6091
# INFO:MyLogger:Log message number 6092
# INFO:MyLogger:Log message number 6093
# INFO:MyLogger:Log message number 6094
# INFO:MyLogger:Log message number 6095
# INFO:MyLogger:Log message number 6096
# INFO:MyLogger:Log message number 6097
# INFO:MyLogger:Log message number 6098
# INFO:MyLogger:Log message number 6099
# INFO:MyLogger:Log message number 6100
# INFO:MyLogger:Log message number 6101
# INFO:MyLogger:Log message number 6102
# INFO:MyLogger:Log message number 6103
# INFO:MyLogger:Log message number 6104
# INFO:MyLogger:Log message number 6105
# INFO:MyLogger:Log message number 6106
# INFO:MyLogger:Log message number 6107
# INFO:MyLogger:Log message number 6108
# INFO:MyLogger:Log message number 6109
# INFO:MyLogger:Log message number 6110
# INFO:MyLogger:Log message number 6111
# INFO:MyLogger:Log message number 6112
# INFO:MyLogger:Log message number 6113
# INFO:MyLogger:Log message number 6114
# INFO:MyLogger:Log message number 6115
# INFO:MyLogger:Log message number 6116
# INFO:MyLogger:Log message number 6117
# INFO:MyLogger:Log message number 6118
# INFO:MyLogger:Log message number 6119
# INFO:MyLogger:Log message number 6120
# INFO:MyLogger:Log message number 6121
# INFO:MyLogger:Log message number 6122
# INFO:MyLogger:Log message number 6123
# INFO:MyLogger:Log message number 6124
# INFO:MyLogger:Log message number 6125
# INFO:MyLogger:Log message number 6126
# INFO:MyLogger:Log message number 6127
# INFO:MyLogger:Log message number 6128
# INFO:MyLogger:Log message number 6129
# INFO:MyLogger:Log message number 6130
# INFO:MyLogger:Log message number 6131
# INFO:MyLogger:Log message number 6132
# INFO:MyLogger:Log message number 6133
# INFO:MyLogger:Log message number 6134
# INFO:MyLogger:Log message number 6135
# INFO:MyLogger:Log message number 6136
# INFO:MyLogger:Log message number 6137
# INFO:MyLogger:Log message number 6138
# INFO:MyLogger:Log message number 6139
# INFO:MyLogger:Log message number 6140
# INFO:MyLogger:Log message number 6141
# INFO:MyLogger:Log message number 6142
# INFO:MyLogger:Log message number 6143
# INFO:MyLogger:Log message number 6144
# INFO:MyLogger:Log message number 6145
# INFO:MyLogger:Log message number 6146
# INFO:MyLogger:Log message number 6147
# INFO:MyLogger:Log message number 6148
# INFO:MyLogger:Log message number 6149
# INFO:MyLogger:Log message number 6150
# INFO:MyLogger:Log message number 6151
# INFO:MyLogger:Log message number 6152
# INFO:MyLogger:Log message number 6153
# INFO:MyLogger:Log message number 6154
# INFO:MyLogger:Log message number 6155
# INFO:MyLogger:Log message number 6156
# INFO:MyLogger:Log message number 6157
# INFO:MyLogger:Log message number 6158
# INFO:MyLogger:Log message number 6159
# INFO:MyLogger:Log message number 6160
# INFO:MyLogger:Log message number 6161
# INFO:MyLogger:Log message number 6162
# INFO:MyLogger:Log message number 6163
# INFO:MyLogger:Log message number 6164
# INFO:MyLogger:Log message number 6165
# INFO:MyLogger:Log message number 6166
# INFO:MyLogger:Log message number 6167
# INFO:MyLogger:Log message number 6168
# INFO:MyLogger:Log message number 6169
# INFO:MyLogger:Log message number 6170
# INFO:MyLogger:Log message number 6171
# INFO:MyLogger:Log message number 6172
# INFO:MyLogger:Log message number 6173
# INFO:MyLogger:Log message number 6174
# INFO:MyLogger:Log message number 6175
# INFO:MyLogger:Log message number 6176
# INFO:MyLogger:Log message number 6177
# INFO:MyLogger:Log message number 6178
# INFO:MyLogger:Log message number 6179
# INFO:MyLogger:Log message number 6180
# INFO:MyLogger:Log message number 6181
# INFO:MyLogger:Log message number 6182
# INFO:MyLogger:Log message number 6183
# INFO:MyLogger:Log message number 6184
# INFO:MyLogger:Log message number 6185
# INFO:MyLogger:Log message number 6186
# INFO:MyLogger:Log message number 6187
# INFO:MyLogger:Log message number 6188
# INFO:MyLogger:Log message number 6189
# INFO:MyLogger:Log message number 6190
# INFO:MyLogger:Log message number 6191
# INFO:MyLogger:Log message number 6192
# INFO:MyLogger:Log message number 6193
# INFO:MyLogger:Log message number 6194
# INFO:MyLogger:Log message number 6195
# INFO:MyLogger:Log message number 6196
# INFO:MyLogger:Log message number 6197
# INFO:MyLogger:Log message number 6198
# INFO:MyLogger:Log message number 6199
# INFO:MyLogger:Log message number 6200
# INFO:MyLogger:Log message number 6201
# INFO:MyLogger:Log message number 6202
# INFO:MyLogger:Log message number 6203
# INFO:MyLogger:Log message number 6204
# INFO:MyLogger:Log message number 6205
# INFO:MyLogger:Log message number 6206
# INFO:MyLogger:Log message number 6207
# INFO:MyLogger:Log message number 6208
# INFO:MyLogger:Log message number 6209
# INFO:MyLogger:Log message number 6210
# INFO:MyLogger:Log message number 6211
# INFO:MyLogger:Log message number 6212
# INFO:MyLogger:Log message number 6213
# INFO:MyLogger:Log message number 6214
# INFO:MyLogger:Log message number 6215
# INFO:MyLogger:Log message number 6216
# INFO:MyLogger:Log message number 6217
# INFO:MyLogger:Log message number 6218
# INFO:MyLogger:Log message number 6219
# INFO:MyLogger:Log message number 6220
# INFO:MyLogger:Log message number 6221
# INFO:MyLogger:Log message number 6222
# INFO:MyLogger:Log message number 6223
# INFO:MyLogger:Log message number 6224
# INFO:MyLogger:Log message number 6225
# INFO:MyLogger:Log message number 6226
# INFO:MyLogger:Log message number 6227
# INFO:MyLogger:Log message number 6228
# INFO:MyLogger:Log message number 6229
# INFO:MyLogger:Log message number 6230
# INFO:MyLogger:Log message number 6231
# INFO:MyLogger:Log message number 6232
# INFO:MyLogger:Log message number 6233
# INFO:MyLogger:Log message number 6234
# INFO:MyLogger:Log message number 6235
# INFO:MyLogger:Log message number 6236
# INFO:MyLogger:Log message number 6237
# INFO:MyLogger:Log message number 6238
# INFO:MyLogger:Log message number 6239
# INFO:MyLogger:Log message number 6240
# INFO:MyLogger:Log message number 6241
# INFO:MyLogger:Log message number 6242
# INFO:MyLogger:Log message number 6243
# INFO:MyLogger:Log message number 6244
# INFO:MyLogger:Log message number 6245
# INFO:MyLogger:Log message number 6246
# INFO:MyLogger:Log message number 6247
# INFO:MyLogger:Log message number 6248
# INFO:MyLogger:Log message number 6249
# INFO:MyLogger:Log message number 6250
# INFO:MyLogger:Log message number 6251
# INFO:MyLogger:Log message number 6252
# INFO:MyLogger:Log message number 6253
# INFO:MyLogger:Log message number 6254
# INFO:MyLogger:Log message number 6255
# INFO:MyLogger:Log message number 6256
# INFO:MyLogger:Log message number 6257
# INFO:MyLogger:Log message number 6258
# INFO:MyLogger:Log message number 6259
# INFO:MyLogger:Log message number 6260
# ...
# INFO:MyLogger:Log message number 9579
# INFO:MyLogger:Log message number 9580
# INFO:MyLogger:Log message number 9581
# INFO:MyLogger:Log message number 9582
# INFO:MyLogger:Log message number 9583
# INFO:MyLogger:Log message number 9584
# INFO:MyLogger:Log message number 9585
# INFO:MyLogger:Log message number 9586
# INFO:MyLogger:Log message number 9587
# INFO:MyLogger:Log message number 9588
# INFO:MyLogger:Log message number 9589
# INFO:MyLogger:Log message number 9590
# INFO:MyLogger:Log message number 9591
# INFO:MyLogger:Log message number 9592
# INFO:MyLogger:Log message number 9593
# INFO:MyLogger:Log message number 9594
# INFO:MyLogger:Log message number 9595
# INFO:MyLogger:Log message number 9596
# INFO:MyLogger:Log message number 9597
# INFO:MyLogger:Log message number 9598
# INFO:MyLogger:Log message number 9599
# INFO:MyLogger:Log message number 9600
# INFO:MyLogger:Log message number 9601
# INFO:MyLogger:Log message number 9602
# INFO:MyLogger:Log message number 9603
# INFO:MyLogger:Log message number 9604
# INFO:MyLogger:Log message number 9605
# INFO:MyLogger:Log message number 9606
# INFO:MyLogger:Log message number 9607
# INFO:MyLogger:Log message number 9608
# INFO:MyLogger:Log message number 9609
# INFO:MyLogger:Log message number 9610
# INFO:MyLogger:Log message number 9611
# INFO:MyLogger:Log message number 9612
# INFO:MyLogger:Log message number 9613
# INFO:MyLogger:Log message number 9614
# INFO:MyLogger:Log message number 9615
# INFO:MyLogger:Log message number 9616
# INFO:MyLogger:Log message number 9617
# INFO:MyLogger:Log message number 9618
# INFO:MyLogger:Log message number 9619
# INFO:MyLogger:Log message number 9620
# INFO:MyLogger:Log message number 9621
# INFO:MyLogger:Log message number 9622
# INFO:MyLogger:Log message number 9623
# INFO:MyLogger:Log message number 9624
# INFO:MyLogger:Log message number 9625
# INFO:MyLogger:Log message number 9626
# INFO:MyLogger:Log message number 9627
# INFO:MyLogger:Log message number 9628
# INFO:MyLogger:Log message number 9629
# INFO:MyLogger:Log message number 9630
# INFO:MyLogger:Log message number 9631
# INFO:MyLogger:Log message number 9632
# INFO:MyLogger:Log message number 9633
# INFO:MyLogger:Log message number 9634
# INFO:MyLogger:Log message number 9635
# INFO:MyLogger:Log message number 9636
# INFO:MyLogger:Log message number 9637
# INFO:MyLogger:Log message number 9638
# INFO:MyLogger:Log message number 9639
# INFO:MyLogger:Log message number 9640
# INFO:MyLogger:Log message number 9641
# INFO:MyLogger:Log message number 9642
# INFO:MyLogger:Log message number 9643
# INFO:MyLogger:Log message number 9644
# INFO:MyLogger:Log message number 9645
# INFO:MyLogger:Log message number 9646
# INFO:MyLogger:Log message number 9647
# INFO:MyLogger:Log message number 9648
# INFO:MyLogger:Log message number 9649
# INFO:MyLogger:Log message number 9650
# INFO:MyLogger:Log message number 9651
# INFO:MyLogger:Log message number 9652
# INFO:MyLogger:Log message number 9653
# INFO:MyLogger:Log message number 9654
# INFO:MyLogger:Log message number 9655
# INFO:MyLogger:Log message number 9656
# INFO:MyLogger:Log message number 9657
# INFO:MyLogger:Log message number 9658
# INFO:MyLogger:Log message number 9659
# INFO:MyLogger:Log message number 9660
# INFO:MyLogger:Log message number 9661
# INFO:MyLogger:Log message number 9662
# INFO:MyLogger:Log message number 9663
# INFO:MyLogger:Log message number 9664
# INFO:MyLogger:Log message number 9665
# INFO:MyLogger:Log message number 9666
# INFO:MyLogger:Log message number 9667
# INFO:MyLogger:Log message number 9668
# INFO:MyLogger:Log message number 9669
# INFO:MyLogger:Log message number 9670
# INFO:MyLogger:Log message number 9671
# INFO:MyLogger:Log message number 9672
# INFO:MyLogger:Log message number 9673
# INFO:MyLogger:Log message number 9674
# INFO:MyLogger:Log message number 9675
# INFO:MyLogger:Log message number 9676
# INFO:MyLogger:Log message number 9677
# INFO:MyLogger:Log message number 9678
# INFO:MyLogger:Log message number 9679
# INFO:MyLogger:Log message number 9680
# INFO:MyLogger:Log message number 9681
# INFO:MyLogger:Log message number 9682
# INFO:MyLogger:Log message number 9683
# INFO:MyLogger:Log message number 9684
# INFO:MyLogger:Log message number 9685
# INFO:MyLogger:Log message number 9686
# INFO:MyLogger:Log message number 9687
# INFO:MyLogger:Log message number 9688
# INFO:MyLogger:Log message number 9689
# INFO:MyLogger:Log message number 9690
# INFO:MyLogger:Log message number 9691
# INFO:MyLogger:Log message number 9692
# INFO:MyLogger:Log message number 9693
# INFO:MyLogger:Log message number 9694
# INFO:MyLogger:Log message number 9695
# INFO:MyLogger:Log message number 9696
# INFO:MyLogger:Log message number 9697
# INFO:MyLogger:Log message number 9698
# INFO:MyLogger:Log message number 9699
# INFO:MyLogger:Log message number 9700
# INFO:MyLogger:Log message number 9701
# INFO:MyLogger:Log message number 9702
# INFO:MyLogger:Log message number 9703
# INFO:MyLogger:Log message number 9704
# INFO:MyLogger:Log message number 9705
# INFO:MyLogger:Log message number 9706
# INFO:MyLogger:Log message number 9707
# INFO:MyLogger:Log message number 9708
# INFO:MyLogger:Log message number 9709
# INFO:MyLogger:Log message number 9710
# INFO:MyLogger:Log message number 9711
# INFO:MyLogger:Log message number 9712
# INFO:MyLogger:Log message number 9713
# INFO:MyLogger:Log message number 9714
# INFO:MyLogger:Log message number 9715
# INFO:MyLogger:Log message number 9716
# INFO:MyLogger:Log message number 9717
# INFO:MyLogger:Log message number 9718
# INFO:MyLogger:Log message number 9719
# INFO:MyLogger:Log message number 9720
# INFO:MyLogger:Log message number 9721
# INFO:MyLogger:Log message number 9722
# INFO:MyLogger:Log message number 9723
# INFO:MyLogger:Log message number 9724
# INFO:MyLogger:Log message number 9725
# INFO:MyLogger:Log message number 9726
# INFO:MyLogger:Log message number 9727
# INFO:MyLogger:Log message number 9728
# INFO:MyLogger:Log message number 9729
# INFO:MyLogger:Log message number 9730
# INFO:MyLogger:Log message number 9731
# INFO:MyLogger:Log message number 9732
# INFO:MyLogger:Log message number 9733
# INFO:MyLogger:Log message number 9734
# INFO:MyLogger:Log message number 9735
# INFO:MyLogger:Log message number 9736
# INFO:MyLogger:Log message number 9737
# INFO:MyLogger:Log message number 9738
# INFO:MyLogger:Log message number 9739
# INFO:MyLogger:Log message number 9740
# INFO:MyLogger:Log message number 9741
# INFO:MyLogger:Log message number 9742
# INFO:MyLogger:Log message number 9743
# INFO:MyLogger:Log message number 9744
# INFO:MyLogger:Log message number 9745
# INFO:MyLogger:Log message number 9746
# INFO:MyLogger:Log message number 9747
# INFO:MyLogger:Log message number 9748
# INFO:MyLogger:Log message number 9749
# INFO:MyLogger:Log message number 9750
# INFO:MyLogger:Log message number 9751
# INFO:MyLogger:Log message number 9752
# INFO:MyLogger:Log message number 9753
# INFO:MyLogger:Log message number 9754
# INFO:MyLogger:Log message number 9755
# INFO:MyLogger:Log message number 9756
# INFO:MyLogger:Log message number 9757
# INFO:MyLogger:Log message number 9758
# INFO:MyLogger:Log message number 9759
# INFO:MyLogger:Log message number 9760
# INFO:MyLogger:Log message number 9761
# INFO:MyLogger:Log message number 9762
# INFO:MyLogger:Log message number 9763
# INFO:MyLogger:Log message number 9764
# INFO:MyLogger:Log message number 9765
# INFO:MyLogger:Log message number 9766
# INFO:MyLogger:Log message number 9767
# INFO:MyLogger:Log message number 9768
# INFO:MyLogger:Log message number 9769
# INFO:MyLogger:Log message number 9770
# INFO:MyLogger:Log message number 9771
# INFO:MyLogger:Log message number 9772
# INFO:MyLogger:Log message number 9773
# INFO:MyLogger:Log message number 9774
# INFO:MyLogger:Log message number 9775
# INFO:MyLogger:Log message number 9776
# INFO:MyLogger:Log message number 9777
# INFO:MyLogger:Log message number 9778
# INFO:MyLogger:Log message number 9779
# INFO:MyLogger:Log message number 9780
# INFO:MyLogger:Log message number 9781
# INFO:MyLogger:Log message number 9782
# INFO:MyLogger:Log message number 9783
# INFO:MyLogger:Log message number 9784
# INFO:MyLogger:Log message number 9785
# INFO:MyLogger:Log message number 9786
# INFO:MyLogger:Log message number 9787
# INFO:MyLogger:Log message number 9788
# INFO:MyLogger:Log message number 9789
# INFO:MyLogger:Log message number 9790
# INFO:MyLogger:Log message number 9791
# INFO:MyLogger:Log message number 9792
# INFO:MyLogger:Log message number 9793
# INFO:MyLogger:Log message number 9794
# INFO:MyLogger:Log message number 9795
# INFO:MyLogger:Log message number 9796
# INFO:MyLogger:Log message number 9797
# INFO:MyLogger:Log message number 9798
# INFO:MyLogger:Log message number 9799
# INFO:MyLogger:Log message number 9800
# INFO:MyLogger:Log message number 9801
# INFO:MyLogger:Log message number 9802
# INFO:MyLogger:Log message number 9803
# INFO:MyLogger:Log message number 9804
# INFO:MyLogger:Log message number 9805
# INFO:MyLogger:Log message number 9806
# INFO:MyLogger:Log message number 9807
# INFO:MyLogger:Log message number 9808
# INFO:MyLogger:Log message number 9809
# INFO:MyLogger:Log message number 9810
# INFO:MyLogger:Log message number 9811
# INFO:MyLogger:Log message number 9812
# INFO:MyLogger:Log message number 9813
# INFO:MyLogger:Log message number 9814
# INFO:MyLogger:Log message number 9815
# INFO:MyLogger:Log message number 9816
# INFO:MyLogger:Log message number 9817
# INFO:MyLogger:Log message number 9818
# INFO:MyLogger:Log message number 9819
# INFO:MyLogger:Log message number 9820
# INFO:MyLogger:Log message number 9821
# INFO:MyLogger:Log message number 9822
# INFO:MyLogger:Log message number 9823
# INFO:MyLogger:Log message number 9824
# INFO:MyLogger:Log message number 9825
# INFO:MyLogger:Log message number 9826
# INFO:MyLogger:Log message number 9827
# INFO:MyLogger:Log message number 9828
# INFO:MyLogger:Log message number 9829
# INFO:MyLogger:Log message number 9830
# INFO:MyLogger:Log message number 9831
# INFO:MyLogger:Log message number 9832
# INFO:MyLogger:Log message number 9833
# INFO:MyLogger:Log message number 9834
# INFO:MyLogger:Log message number 9835
# INFO:MyLogger:Log message number 9836
# INFO:MyLogger:Log message number 9837
# INFO:MyLogger:Log message number 9838
# INFO:MyLogger:Log message number 9839
# INFO:MyLogger:Log message number 9840
# INFO:MyLogger:Log message number 9841
# INFO:MyLogger:Log message number 9842
# INFO:MyLogger:Log message number 9843
# INFO:MyLogger:Log message number 9844
# INFO:MyLogger:Log message number 9845
# INFO:MyLogger:Log message number 9846
# INFO:MyLogger:Log message number 9847
# INFO:MyLogger:Log message number 9848
# INFO:MyLogger:Log message number 9849
# INFO:MyLogger:Log message number 9850
# INFO:MyLogger:Log message number 9851
# INFO:MyLogger:Log message number 9852
# INFO:MyLogger:Log message number 9853
# INFO:MyLogger:Log message number 9854
# INFO:MyLogger:Log message number 9855
# INFO:MyLogger:Log message number 9856
# INFO:MyLogger:Log message number 9857
# INFO:MyLogger:Log message number 9858
# INFO:MyLogger:Log message number 9859
# INFO:MyLogger:Log message number 9860
# INFO:MyLogger:Log message number 9861
# INFO:MyLogger:Log message number 9862
# INFO:MyLogger:Log message number 9863
# INFO:MyLogger:Log message number 9864
# INFO:MyLogger:Log message number 9865
# INFO:MyLogger:Log message number 9866
# INFO:MyLogger:Log message number 9867
# INFO:MyLogger:Log message number 9868
# INFO:MyLogger:Log message number 9869
# INFO:MyLogger:Log message number 9870
# INFO:MyLogger:Log message number 9871
# INFO:MyLogger:Log message number 9872
# INFO:MyLogger:Log message number 9873
# INFO:MyLogger:Log message number 9874
# INFO:MyLogger:Log message number 9875
# INFO:MyLogger:Log message number 9876
# INFO:MyLogger:Log message number 9877
# INFO:MyLogger:Log message number 9878
# INFO:MyLogger:Log message number 9879
# INFO:MyLogger:Log message number 9880
# INFO:MyLogger:Log message number 9881
# INFO:MyLogger:Log message number 9882
# INFO:MyLogger:Log message number 9883
# INFO:MyLogger:Log message number 9884
# INFO:MyLogger:Log message number 9885
# INFO:MyLogger:Log message number 9886
# INFO:MyLogger:Log message number 9887
# INFO:MyLogger:Log message number 9888
# INFO:MyLogger:Log message number 9889
# INFO:MyLogger:Log message number 9890
# INFO:MyLogger:Log message number 9891
# INFO:MyLogger:Log message number 9892
# INFO:MyLogger:Log message number 9893
# INFO:MyLogger:Log message number 9894
# INFO:MyLogger:Log message number 9895
# INFO:MyLogger:Log message number 9896
# INFO:MyLogger:Log message number 9897
# INFO:MyLogger:Log message number 9898
# INFO:MyLogger:Log message number 9899
# INFO:MyLogger:Log message number 9900
# INFO:MyLogger:Log message number 9901
# INFO:MyLogger:Log message number 9902
# INFO:MyLogger:Log message number 9903
# INFO:MyLogger:Log message number 9904
# INFO:MyLogger:Log message number 9905
# INFO:MyLogger:Log message number 9906
# INFO:MyLogger:Log message number 9907
# INFO:MyLogger:Log message number 9908
# INFO:MyLogger:Log message number 9909
# INFO:MyLogger:Log message number 9910
# INFO:MyLogger:Log message number 9911
# INFO:MyLogger:Log message number 9912
# INFO:MyLogger:Log message number 9913
# INFO:MyLogger:Log message number 9914
# INFO:MyLogger:Log message number 9915
# INFO:MyLogger:Log message number 9916
# INFO:MyLogger:Log message number 9917
# INFO:MyLogger:Log message number 9918
# INFO:MyLogger:Log message number 9919
# INFO:MyLogger:Log message number 9920
# INFO:MyLogger:Log message number 9921
# INFO:MyLogger:Log message number 9922
# INFO:MyLogger:Log message number 9923
# INFO:MyLogger:Log message number 9924
# INFO:MyLogger:Log message number 9925
# INFO:MyLogger:Log message number 9926
# INFO:MyLogger:Log message number 9927
# INFO:MyLogger:Log message number 9928
# INFO:MyLogger:Log message number 9929
# INFO:MyLogger:Log message number 9930
# INFO:MyLogger:Log message number 9931
# INFO:MyLogger:Log message number 9932
# INFO:MyLogger:Log message number 9933
# INFO:MyLogger:Log message number 9934
# INFO:MyLogger:Log message number 9935
# INFO:MyLogger:Log message number 9936
# INFO:MyLogger:Log message number 9937
# INFO:MyLogger:Log message number 9938
# INFO:MyLogger:Log message number 9939
# INFO:MyLogger:Log message number 9940
# INFO:MyLogger:Log message number 9941
# INFO:MyLogger:Log message number 9942
# INFO:MyLogger:Log message number 9943
# INFO:MyLogger:Log message number 9944
# INFO:MyLogger:Log message number 9945
# INFO:MyLogger:Log message number 9946
# INFO:MyLogger:Log message number 9947
# INFO:MyLogger:Log message number 9948
# INFO:MyLogger:Log message number 9949
# INFO:MyLogger:Log message number 9950
# INFO:MyLogger:Log message number 9951
# INFO:MyLogger:Log message number 9952
# INFO:MyLogger:Log message number 9953
# INFO:MyLogger:Log message number 9954
# INFO:MyLogger:Log message number 9955
# INFO:MyLogger:Log message number 9956
# INFO:MyLogger:Log message number 9957
# INFO:MyLogger:Log message number 9958
# INFO:MyLogger:Log message number 9959
# INFO:MyLogger:Log message number 9960
# INFO:MyLogger:Log message number 9961
# INFO:MyLogger:Log message number 9962
# INFO:MyLogger:Log message number 9963
# INFO:MyLogger:Log message number 9964
# INFO:MyLogger:Log message number 9965
# INFO:MyLogger:Log message number 9966
# INFO:MyLogger:Log message number 9967
# INFO:MyLogger:Log message number 9968
# INFO:MyLogger:Log message number 9969
# INFO:MyLogger:Log message number 9970
# INFO:MyLogger:Log message number 9971
# INFO:MyLogger:Log message number 9972
# INFO:MyLogger:Log message number 9973
# INFO:MyLogger:Log message number 9974
# INFO:MyLogger:Log message number 9975
# INFO:MyLogger:Log message number 9976
# INFO:MyLogger:Log message number 9977
# INFO:MyLogger:Log message number 9978
# INFO:MyLogger:Log message number 9979
# INFO:MyLogger:Log message number 9980
# INFO:MyLogger:Log message number 9981
# INFO:MyLogger:Log message number 9982
# INFO:MyLogger:Log message number 9983
# INFO:MyLogger:Log message number 9984
# INFO:MyLogger:Log message number 9985
# INFO:MyLogger:Log message number 9986
# INFO:MyLogger:Log message number 9987
# INFO:MyLogger:Log message number 9988
# INFO:MyLogger:Log message number 9989
# INFO:MyLogger:Log message number 9990
# INFO:MyLogger:Log message number 9991
# INFO:MyLogger:Log message number 9992
# INFO:MyLogger:Log message number 9993
# INFO:MyLogger:Log message number 9994
# INFO:MyLogger:Log message number 9995
# INFO:MyLogger:Log message number 9996
# INFO:MyLogger:Log message number 9997
# INFO:MyLogger:Log message number 9998
# INFO:MyLogger:Log message number 9999

# %% [markdown]
# ### **19. Write a program that handles both IndexError and KeyError using a try-except block.**
#
# **Answer**:

# %%
try:
    lst = [1, 2, 3]
    print(lst[5])
    d = {"a": 1}
    print(d["b"])
except IndexError:
    print("List index out of range")
except KeyError:
    print("Key not found in dictionary")
# Out:
# List index out of range

# %% [markdown]
# ### **20. How would you open a file and read its contents using a context manager in Python?**
#
# **Answer**:
#
# This is the most common and recommended way, using the `with` statement.

# %%
# Create a dummy file
with open("context_manager_example.txt", "w") as f:
    f.write("This file was opened using a context manager.\n")
    f.write("It ensures the file is automatically closed.")

try:
    # Open the file using a context manager
    with open("context_manager_example.txt", "r") as file:
        content = file.read()
        print("File content read successfully:")
        print(content)
    # The file is automatically closed here, even if errors occurred inside the 'with' block
    print("\nFile 'context_manager_example.txt' is now closed.")

except FileNotFoundError:
    print("Error: File not found.")
except IOError as e:
    print(f"An I/O error occurred: {e}")
# Out:
# File content read successfully:
# This file was opened using a context manager.
# It ensures the file is automatically closed.
#
# File 'context_manager_example.txt' is now closed.

# %% [markdown]
# ### **21. Write a Python program that reads a file and prints the number of occurrences of a specific word.**
#
# **Answer**:

# %%
def count_word_occurrences(filename, word_to_find):
    count = 0
    word_to_find_lower = word_to_find.lower() # Case-insensitive search
    try:
        with open(filename, "r") as file:
            for line in file:
                # Split line into words and convert to lowercase for case-insensitive comparison
                words_in_line = line.lower().split()
                count += words_in_line.count(word_to_find_lower)
        print(f"The word '{word_to_find}' appears {count} times in '{filename}'.")
        return count
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
        return -1
    except IOError as e:
        print(f"An I/O error occurred while reading '{filename}': {e}")
        return -1

# Create a dummy file
with open("word_search_test.txt", "w") as f:
    f.write("Python is a powerful language. Python is versatile.\n")
    f.write("Learn Python to become a great programmer. python.\n")
    f.write("Python IDEs are great.")

print("--- Searching for 'Python' ---")
count_word_occurrences("word_search_test.txt", "Python")

print("\n--- Searching for 'is' ---")
count_word_occurrences("word_search_test.txt", "is")

print("\n--- Searching for a non-existent word ---")
count_word_occurrences("word_search_test.txt", "java")

print("\n--- Searching in a non-existent file ---")
count_word_occurrences("non_existent_word_file.txt", "test")
# Out:
# --- Searching for 'Python' ---
# The word 'Python' appears 4 times in 'word_search_test.txt'.
#
# --- Searching for 'is' ---
# The word 'is' appears 2 times in 'word_search_test.txt'.
#
# --- Searching for a non-existent word ---
# The word 'java' appears 0 times in 'word_search_test.txt'.
#
# --- Searching in a non-existent file ---
# Error: The file 'non_existent_word_file.txt' was not found.
# -1

# %% [markdown]
# ### **22. How can you check if a file is empty before attempting to read its contents?**
#
# **Answer**:
#
# You can check a file's size using `os.path.getsize()`. If it returns 0, the file is empty.

# %%
import os

def check_and_read_file(filename):
    if not os.path.exists(filename):
        print(f"Error: The file '{filename}' does not exist.")
        return

    try:
        if os.path.getsize(filename) == 0:
            print(f"The file '{filename}' is empty.")
        else:
            print(f"The file '{filename}' is not empty. Reading content:")
            with open(filename, "r") as f:
                print(f.read())
    except OSError as e: # Catches various OS-related errors like permission issues
        print(f"Error accessing file '{filename}': {e}")

# Create dummy files
with open("non_empty_check.txt", "w") as f:
    f.write("Some content here.")
with open("empty_check.txt", "w") as f:
    pass # Creates an empty file

print("--- Checking non_empty_check.txt ---")
check_and_read_file("non_empty_check.txt")

print("\n--- Checking empty_check.txt ---")
check_and_read_file("empty_check.txt")

print("\n--- Checking non_existent_file_check.txt ---")
check_and_read_file("non_existent_file_check.txt")
# Out:
# --- Checking non_empty_check.txt ---
# The file 'non_empty_check.txt' is not empty. Reading content:
# Some content here.
#
# --- Checking empty_check.txt ---
# The file 'empty_check.txt' is empty.
#
# --- Checking non_existent_file_check.txt ---
# Error: The file 'non_existent_file_check.txt' does not exist.

# %% [markdown]
# ### **23. Write a Python program that writes to a log file when an error occurs during file handling.**
#
# **Answer**:
#
# This combines file handling with logging for error reporting.

# %%
import logging
import os

# Define the name of the log file for errors
LOG_FILE_NAME = "file_handling_errors.log"

# --- Logging Configuration ---
# It's good practice to ensure a clean log file for demonstration,
# so we'll remove it if it exists from a previous run.
if os.path.exists(LOG_FILE_NAME):
    try:
        os.remove(LOG_FILE_NAME)
        print(f"Cleaned up previous log file: {LOG_FILE_NAME}")
    except OSError as e:
        print(f"Error removing old log file {LOG_FILE_NAME}: {e}")

# Configure the logging system
# - filename: Specifies the file to which logs will be written.
# - level: Sets the minimum logging level to capture. Here, only messages
#          of level ERROR and higher (CRITICAL) will be written to the file.
# - format: Defines the layout of the log messages.
#   - %(asctime)s: Current time when the log record was created.
#   - %(levelname)s: The text logging level for the message (e.g., ERROR).
#   - %(module)s: The name of the module where the log call was made.
#   - %(lineno)d: The line number where the log call was made.
#   - %(message)s: The actual log message.
logging.basicConfig(
    filename=LOG_FILE_NAME,
    level=logging.ERROR, # Only log ERROR and CRITICAL messages to the file
    format='%(asctime)s - %(levelname)s - %(module)s:%(lineno)d - %(message)s'
)

# Get a logger instance. It's good practice to get a named logger.
logger = logging.getLogger('file_handler_app')

# --- Function to perform safe file reading ---
def safe_file_read(filename):
    """
    Attempts to read the content of a file.
    Logs an error message to LOG_FILE_NAME if any file handling error occurs.

    Args:
        filename (str): The path to the file to be read.
    """
    print(f"\nAttempting to read file: '{filename}'")
    try:
        with open(filename, "r") as file:
            content = file.read()
            print(f"Successfully read '{filename}'. Content length: {len(content)} characters.")
            # Optionally log success, but won't go to file with ERROR level
            logger.info(f"Successfully read file: {filename}")
    except FileNotFoundError:
        # Log a specific error for files that do not exist
        error_msg = f"File not found: The file '{filename}' does not exist."
        logger.error(error_msg, exc_info=True) # exc_info=True adds the traceback
        print(f"Operation failed: {error_msg}. Check '{LOG_FILE_NAME}' for details.")
    except PermissionError:
        # Log a specific error for permission issues
        error_msg = f"Permission denied: You do not have sufficient permissions to read '{filename}'."
        logger.error(error_msg, exc_info=True)
        print(f"Operation failed: {error_msg}. Check '{LOG_FILE_NAME}' for details.")
    except IOError as e:
        # Catch other general I/O errors (e.g., disk full, corrupted file)
        error_msg = f"An I/O error occurred while reading '{filename}': {e}"
        logger.error(error_msg, exc_info=True)
        print(f"Operation failed: {error_msg}. Check '{LOG_FILE_NAME}' for details.")
    except Exception as e:
        # Catch any other unexpected exceptions as critical
        error_msg = f"An unexpected critical error occurred during file operation on '{filename}': {type(e).__name__} - {e}"
        logger.critical(error_msg, exc_info=True)
        print(f"Operation failed: {error_msg}. Check '{LOG_FILE_NAME}' for details.")

# --- Test Cases ---

# Test Case 1: Reading an existing file (success)
existing_file = "my_document.txt"
with open(existing_file, "w") as f:
    f.write("This is a sample document for testing file reading.")
safe_file_read(existing_file)

# Test Case 2: Reading a non-existent file (FileNotFoundError)
non_existent_file = "non_existent_document.txt"
safe_file_read(non_existent_file)

# Test Case 3: Simulating a PermissionError (platform-dependent)
# On Unix-like systems (Linux, macOS), you can create a file and remove read permissions.
# On Windows, simulating this directly in Python is harder without admin rights or specific file locks.
# For demonstration, we'll create a dummy file and try to set permissions,
# but the actual PermissionError might not occur depending on your OS and user privileges.
permission_denied_file = "restricted_access.txt"
try:
    with open(permission_denied_file, "w") as f:
        f.write("This file has restricted access.")
    # Attempt to change permissions to be unreadable for others (or current user)
    # This might require specific OS capabilities or admin rights.
    # For a general demo, this might not always trigger PermissionError.
    # On Linux/macOS, 0o000 means no permissions for anyone.
    os.chmod(permission_denied_file, 0o000)
    safe_file_read(permission_denied_file)
except OSError as e:
    print(f"\nCould not set permissions for '{permission_denied_file}' to test PermissionError: {e}")
    print("Skipping PermissionError test as OS did not allow permission change.")
finally:
    # Clean up the restricted file
    if os.path.exists(permission_denied_file):
        os.remove(permission_denied_file)


print(f"\nProgram finished. Check the file '{LOG_FILE_NAME}' for detailed error logs.")
# Out:
# ERROR:file_handler_app:File not found: The file 'non_existent_document.txt' does not exist.
# Traceback (most recent call last):
#   File "/tmp/ipython-input-27-510298512.py", line 47, in safe_file_read
#     with open(filename, "r") as file:
#          ^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'non_existent_document.txt'
# Attempting to read file: 'my_document.txt'
# Successfully read 'my_document.txt'. Content length: 51 characters.
#
# Attempting to read file: 'non_existent_document.txt'
# Operation failed: File not found: The file 'non_existent_document.txt' does not exist.. Check 'file_handling_errors.log' for details.
#
# Attempting to read file: 'restricted_access.txt'
# Successfully read 'restricted_access.txt'. Content length: 32 characters.
#
# Program finished. Check the file 'file_handling_errors.log' for detailed error logs.
